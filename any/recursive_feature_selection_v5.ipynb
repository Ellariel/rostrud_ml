# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#base_dir = '/content/drive/MyDrive/ИЦ им. Ханны Арендт/Мобилизация/'
base_dir = '/content/drive/MyDrive/'
before_date = '03.11.2022'
after_date = '01.02.2023'

# %% [markdown]
# ### setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, pickle
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor
import warnings
warnings.filterwarnings("ignore")

def get_stars(p):
    if p < 0.001:
        return '****'
    if p < 0.01:
        return '***'
    if p < 0.05:
        return '**'
    if p < 0.10:
        return '*'
    return ''

def get_APA(ols, sig=False): #R^2=.34, F(1,416)=6.71, p=.009
  r_sq = f'{ols.rsquared:.2f}'[1:]
  df_m = int(ols.df_model)
  df_r = int(ols.df_resid)
  f_v = f'{ols.fvalue:.2f}'[1:] if ols.fvalue < 1 else f'{ols.fvalue:.2f}'
  p_v = f'{ols.f_pvalue:.3f}'[1:] if ols.f_pvalue >= 0.001 else '.001'
  lvl = '<' if ols.f_pvalue < 0.001 else '='
  sig = get_stars(ols.f_pvalue) if sig else ''
  return f"R²={r_sq}, F({df_m}, {df_r})={f_v}, p{lvl}{p_v}{sig}"

def calc_OLS(data, y, x, standardized=False, rename_dict=None):
    _d = data
    if standardized:
      scaler = StandardScaler()
      scaler.fit(_d)
      __d = scaler.transform(_d)
      __d=pd.DataFrame(__d)
      __d.columns = _d.columns
      _d = __d
    f = f'{y} ~ 1 + ' + '+'.join([i for i in x if i in _d])
    print(f)
    ols = smf.ols(f, _d).fit(cov_type='HC1')
    #print(ols.summary())
    robust = smf.rlm(f, _d, M=sm.robust.norms.HuberT()).fit() #TrimmedMean(0.5)
    #print(robust.summary())
    base_ols = pd.read_html(ols.summary().tables[1].as_html(), header=0, index_col=0)[0].rename(columns={'P>|z|' : 'p-value',
                                                                                  'std err' : 'std_err',
                                                                                  '[0.025' : 'CIL',
                                                                                  '0.975]' : 'CIR'})
    base_ols['sig'] = [get_stars(i) for i in base_ols['p-value']]
    robust_ols = pd.read_html(robust.summary().tables[1].as_html(), header=0, index_col=0)[0].rename(columns={'P>|z|' : 'p-value',
                                                                                  'std err' : 'std_err',
                                                                                  '[0.025' : 'CIL',
                                                                                  '0.975]' : 'CIR'})
    robust_ols['sig'] = [get_stars(i) for i in robust_ols['p-value']]
    robust_ols.columns = [i+'_robust' for i in robust_ols.columns]
    x = pd.Series(x).rename('feature')
    x = pd.concat([x, x.rename('i')], axis=1).set_index('i')
    robust_ols = x.join(robust_ols, how='left')
    results = robust_ols.join(base_ols, how='left').reset_index()
    if 'i' in results:
      results.drop('i', axis=1, inplace=True)
    if rename_dict:
        results['feature'] = results['feature'].apply(lambda x: rename_dict[x] if x in rename_dict else x)
    return results, get_APA(ols)

# %% [markdown]
# ### data load

# %%
main_df_norm = pd.read_csv(os.path.join(base_dir, 'main_df_norm.csv'))

# %%
cv_mean_count_diff = pd.read_csv(os.path.join(base_dir, 'cv_mean_count_diff.csv'), sep=';')

# %%
excess_before = pd.read_csv(os.path.join(base_dir, f'cv_excess_{before_date}.csv'), sep=';').rename(columns={'excess_value': 'excess_value_before'})
excess_after = pd.read_csv(os.path.join(base_dir, f'cv_excess_{after_date}.csv'), sep=';').rename(columns={'excess_value': 'excess_value_after'})
excess = pd.merge(excess_before, excess_after, on='region_name')[['region_name', 'excess_value_before', 'excess_value_after']]
r = pd.read_csv(os.path.join(base_dir, f'regions.csv'), sep=';', dtype='str')
excess = excess.merge(r[['region_code', 'region_name']], how='left', on='region_name')
excess['region_code'] = pd.to_numeric(excess['region_code'])

# %%
production = pd.read_csv(os.path.join(base_dir, f'production.csv'), sep=',')
production = production.merge(r[['region_code', 'region_name']], how='left', on='region_name')
production['region_code'] = pd.to_numeric(production['region_code'])

# %%
dotation = pd.read_csv(os.path.join(base_dir, f'dotations_2022.csv'), sep=',')

# %%
vrp_struct = pd.read_excel(os.path.join(base_dir, f'vrp-struct.xlsx')).merge(r[['region_code', 'region_name']], how='left', on='region_name').drop('region_name', axis=1)
vrp_struct['region_code'] = pd.to_numeric(vrp_struct['region_code'])

# %%
with open(os.path.join(base_dir, 'industry_dict.pickle'), 'rb') as pf:
    vac_industry_dict = pickle.load(pf)
with open(os.path.join(base_dir, 'vac_industry.pickle'), 'rb') as pf:
    vac_industry = pickle.load(pf)
len(vac_industry)
# Out:
# 530510

# %%
vac = vac_industry.copy()
vac = vac[(vac['date_create'] >= '2022-09-21') & (vac['date_create'] <= '2022-12-31')]
vac = vac_industry.groupby('region_code').count()[['id']].rename(columns={'id' : 'vac_count'}).reset_index()
vac['region_code'] = pd.to_numeric(vac['region_code'])
if 'region_name' in vac:
  vac.drop('region_name', axis=1, inplace=True)

# %%
'''
vac_count = vac_industry.groupby('region_code').mean().rename(columns={'id' : 'vac_count'}).reset_index()
vac_count['region_code'] = pd.to_numeric(vac_count['region_code'])
if 'region_name' in vac_count:
  vac_count.drop('region_name', axis=1, inplace=True)
'''
# Out:
# "\nvac_count = vac_industry.groupby('region_code').mean().rename(columns={'id' : 'vac_count'}).reset_index()\nvac_count['region_code'] = pd.to_numeric(vac_count['region_code'])\nif 'region_name' in vac_count:\n  vac_count.drop('region_name', axis=1, inplace=True)\n"

# %%
#Лесозаготовки:
#https://xn--80aegj1b5e.xn--p1ai/publication/lesopromyshlennyy-kompleks
#Амурской, Архангельской, Иркутской, Кировской, Костромской, Пермской, Томской областей; Красноярского и Хабаровского края; в Республике Коми. Челябинская свердловская тюменская
#Одним из самых развитых регионов, который имеет на своей территории богатые лесные ресурсы и производит лесозаготовку в больших объемах – это Урал.
#Лесная промышленность также развита в Карелии, республики Удмуртии, Тюменской области и Архангельской области. В этих регионах располагаются самые крупные предприятия лесопиления.
#https://communa.ru/prochie_novosti_07_2019/lesnaya-promyshlennost-v-rossii-gde-nakhodyatsya-osnovnye-proizvodstva/
#https://fabricators.ru/proizvodstvo/lesozagotovitelnye-predpriyatiya
r['forest'] = 0
r.loc[r.region_name == 'Архангельская область', 'forest'] = 1
r.loc[r.region_name == 'Удмуртская Республика', 'forest'] = 1
r.loc[r.region_name == 'Республика Карелия', 'forest'] = 1
r.loc[r.region_name == 'Челябинская область', 'forest'] = 1
r.loc[r.region_name == 'Тюменская область', 'forest'] = 1
r.loc[r.region_name == 'Свердловская область', 'forest'] = 1
r.loc[r.region_name == 'Республика Коми', 'forest'] = 1
r.loc[r.region_name == 'Хабаровский край', 'forest'] = 1
r.loc[r.region_name == 'Красноярский край', 'forest'] = 1
r.loc[r.region_name == 'Томская область', 'forest'] = 1
r.loc[r.region_name == 'Пермский край', 'forest'] = 1
r.loc[r.region_name == 'Костромская область', 'forest'] = 1
r.loc[r.region_name == 'Кировская область', 'forest'] = 1
r.loc[r.region_name == 'Иркутская область', 'forest'] = 1
r.loc[r.region_name == 'Амурская область', 'forest'] = 1
r['auto'] = 0
#https://xn--80aegj1b5e.xn--p1ai/factories/avtomobilnye-zavody
r.loc[r.region_name == 'Брянская область', 'auto'] = 1
r.loc[r.region_name == 'Калужская область', 'auto'] = 1
r.loc[r.region_name == 'Московская область', 'auto'] = 1
r.loc[r.region_name == 'Калининградская область', 'auto'] = 1
r.loc[r.region_name == 'Ленинградская область', 'auto'] = 1
r.loc[r.region_name == 'Челябинская область', 'auto'] = 1
r.loc[r.region_name == 'Республика Татарстан', 'auto'] = 1
r.loc[r.region_name == 'Удмуртская Республика', 'auto'] = 1
r.loc[r.region_name == 'Нижегородская область', 'auto'] = 1
r.loc[r.region_name == 'Самарская область', 'auto'] = 1
r.loc[r.region_name == 'Ульяновская область', 'auto'] = 1
r.loc[r.region_name == 'Тюменская область', 'auto'] = 1
r.loc[r.region_name == 'Липецкая область', 'auto'] = 1
r.loc[r.region_name == 'Ставропольский край', 'auto'] = 1
r.loc[r.region_name == 'Воронежская область', 'auto'] = 1
#https://ru.wikipedia.org/wiki/%D0%9E%D0%B1%D0%BE%D1%80%D0%BE%D0%BD%D0%BD%D0%BE-%D0%BF%D1%80%D0%BE%D0%BC%D1%8B%D1%88%D0%BB%D0%B5%D0%BD%D0%BD%D1%8B%D0%B9_%D0%BA%D0%BE%D0%BC%D0%BF%D0%BB%D0%B5%D0%BA%D1%81_%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B8#:~:text=%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B5%20%D0%BA%D0%BE%D0%BC%D0%BF%D0%B0%D0%BD%D0%B8%D0%B8%20%D0%9E%D0%9F%D0%9A%3A%20%C2%AB%D0%A0%D0%BE%D1%81%D1%82%D0%B5%D1%85%C2%BB,%D0%B7%D0%B0%D0%B2%D0%BE%D0%B4%2C%20%D0%92%D0%BE%D1%82%D0%BA%D0%B8%D0%BD%D1%81%D0%BA%D0%B8%D0%B9%20%D0%B7%D0%B0%D0%B2%D0%BE%D0%B4%20%D0%B8%20%D0%B4%D1%80%D1%83%D0%B3%D0%B8%D0%B5.
r['vpk'] = 0
r.loc[r.region_name == 'Нижегородская область', 'vpk'] = 1
r.loc[r.region_name == 'Пензенская область', 'vpk'] = 1
r.loc[r.region_name == 'Свердловская область', 'vpk'] = 1
r.loc[r.region_name == 'Челябинская область', 'vpk'] = 1
r.loc[r.region_name == 'Томская область', 'vpk'] = 1
r.loc[r.region_name == 'Красноярский край', 'vpk'] = 1
r.loc[r.region_name == 'Иркутская область', 'vpk'] = 1
r.loc[r.region_name == 'Московская область', 'vpk'] = 1
r.loc[r.region_name == 'Калининградская область', 'vpk'] = 1
r.loc[r.region_name == 'Ленинградская область', 'vpk'] = 1
r.loc[r.region_name == 'Воронежская область', 'vpk'] = 1
r.loc[r.region_name == 'Ростовская область', 'vpk'] = 1
r.loc[r.region_name == 'Волгоградская область', 'vpk'] = 1
r.loc[r.region_name == 'Саратовская область', 'vpk'] = 1
r.loc[r.region_name == 'Республика Татарстан', 'vpk'] = 1
r.loc[r.region_name == 'Ульяновская область', 'vpk'] = 1
r.loc[r.region_name == 'Самарская область', 'vpk'] = 1
r.loc[r.region_name == 'Кировская область', 'vpk'] = 1
r.loc[r.region_name == 'Удмуртская Республика', 'vpk'] = 1
r.loc[r.region_name == 'Пермский край', 'vpk'] = 1
r.loc[r.region_name == 'Омская область', 'vpk'] = 1
r.loc[r.region_name == 'Алтайский край', 'vpk'] = 1
r.loc[r.region_name == 'Новосибирская область', 'vpk'] = 1
r.loc[r.region_name == 'Смоленская область', 'vpk'] = 1
r.loc[r.region_name == 'Калужская область', 'vpk'] = 1
r.loc[r.region_name == 'Республика Башкортостан', 'vpk'] = 1
r.loc[r.region_name == 'Республика Бурятия', 'vpk'] = 1
r.loc[r.region_name == 'Хабаровский край', 'vpk'] = 1
r.loc[r.region_name == 'Приморский край', 'vpk'] = 1
r.loc[r.region_name == 'г. Санкт-Петербург', 'vpk'] = 1
'''
С Украиной граничат 6 субъектов РФ. Брянская, Курская, Белгородская, Воронежская области имеют границу по суше,
Краснодарский край граничит с Украиной по Азовскому морю и Керченскому проливу,
а Ростовская область имеет комбинированную границу – по суше и Азовскому морю.
'''
r['border'] = 0
r.loc[r.region_name == 'Брянская область', 'border'] = 1
r.loc[r.region_name == 'Курская область', 'border'] = 1
r.loc[r.region_name == 'Белгородская область', 'border'] = 1
r.loc[r.region_name == 'Воронежская область', 'border'] = 1
r.loc[r.region_name == 'Ростовская область', 'border'] = 1
r.loc[r.region_name == 'Краснодарский край', 'border'] = 1

# %%
r['region_code'] = pd.to_numeric(r['region_code'])
main_df_norm = pd.merge(main_df_norm, vac, on='region_code')
main_df_norm = pd.merge(main_df_norm, r[['region_code', 'forest', 'auto', 'vpk', 'border']], on='region_code')
main_df_norm = pd.merge(main_df_norm, cv_mean_count_diff, on='region_code')
main_df_norm = pd.merge(main_df_norm, vrp_struct, on='region_code')
main_df_norm = pd.merge(main_df_norm, excess, on='region_code')
main_df_norm = pd.merge(main_df_norm, dotation[['dotation_2022', 'region_code', 'mean_unempl_days', 'mean_unempl_days_alltime']], on='region_code')
main_df_norm = pd.merge(main_df_norm, production[['max_drop', 'sum_change', 'sum_drop', 'max_drop_manuf',
       'sum_change_manuf', 'sum_drop_manuf', 'max_drop_power',
       'sum_change_power', 'sum_drop_power', 'max_drop_water',
       'sum_change_water', 'sum_drop_water', 'region_code']], on='region_code')

# %%
if 'region_name' in main_df_norm:
  main_df_norm.drop('region_name', axis=1, inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(main_df_norm)
main_df_norm_scaled = scaler.transform(main_df_norm)
main_df_norm_scaled=pd.DataFrame(main_df_norm_scaled)
main_df_norm_scaled.columns = main_df_norm.columns

# %%
main_df_norm_scaled.rename(columns={'Добыча полезных ископаемых': 'dobycha',
                             'Строительство' : 'stritelstvo',
                             'Оптовая торговля' : 'torgovlya'}, inplace=True)

# %%
main_df_norm_scaled.to_csv(os.path.join(base_dir, 'main_df_norm_scaled.csv'), index=False, sep=';')

# %%
main_df_norm_scaled.columns.tolist()
# Out:
# ['economic_growth',
#  'population',
#  'excessive_voices',
#  'gossluz',
#  'income',
#  'vote_turnout',
#  'rate_yes',
#  'internet',
#  '_8014006',
#  'city_people',
#  'mans_only',
#  'salary',
#  'subsidii_flat',
#  'subsidised_families_flat',
#  'migration',
#  'hospital',
#  'subsidii',
#  'weddings',
#  'region_code',
#  'cv',
#  'poteri',
#  'mobiliz',
#  'dobrovol',
#  'Место',
#  'Соотношение среднедушевого долга по кредитам и годовой зарплаты в начале 2022 г., %',
#  'indebted',
#  'Изменение задолженности на\xa0одного человека за\xa0год, тыс. руб.',
#  'poverty_ratio',
#  'zaderzania',
#  'antiwar_zaderzania',
#  'mean_living_subsid',
#  'vac_count',
#  'forest',
#  'auto',
#  'vpk',
#  'border',
#  'cv_mean_count_diff2022',
#  'cv_mean_count_diff2023',
#  'cv_mean_count_difffeb',
#  'сх, лес, рыба',
#  'dobycha',
#  'Обрабатывающее произв',
#  'Электроэнергия, газ',
#  'Водоснаб',
#  'stritelstvo',
#  'torgovlya',
#  'Траспорт',
#  'Общественное питание, гостиницы',
#  'Информация и связь',
#  'Финансы и страхование',
#  'Недвижимость',
#  'Наука и техника',
#  'администр',
#  'госуправление',
#  'образование',
#  'здравоохранение',
#  'культура и спорт',
#  'прочие',
#  'домохозяйства',
#  'excess_value_before',
#  'excess_value_after',
#  'dotation_2022',
#  'mean_unempl_days',
#  'mean_unempl_days_alltime',
#  'max_drop',
#  'sum_change',
#  'sum_drop',
#  'max_drop_manuf',
#  'sum_change_manuf',
#  'sum_drop_manuf',
#  'max_drop_power',
#  'sum_change_power',
#  'sum_drop_power',
#  'max_drop_water',
#  'sum_change_water',
#  'sum_drop_water']

# %% [markdown]
# ### hypoteses testing

# %%
main_df_norm.columns.to_list()
# Out:
# ['economic_growth',
#  'population',
#  'excessive_voices',
#  'gossluz',
#  'income',
#  'vote_turnout',
#  'rate_yes',
#  'internet',
#  '_8014006',
#  'city_people',
#  'mans_only',
#  'salary',
#  'subsidii_flat',
#  'subsidised_families_flat',
#  'migration',
#  'hospital',
#  'subsidii',
#  'weddings',
#  'region_code',
#  'cv',
#  'poteri',
#  'mobiliz',
#  'dobrovol',
#  'Место',
#  'Соотношение среднедушевого долга по кредитам и годовой зарплаты в начале 2022 г., %',
#  'indebted',
#  'Изменение задолженности на\xa0одного человека за\xa0год, тыс. руб.',
#  'poverty_ratio',
#  'zaderzania',
#  'antiwar_zaderzania',
#  'mean_living_subsid',
#  'vac_count',
#  'forest',
#  'auto',
#  'vpk',
#  'border',
#  'cv_mean_count_diff2022',
#  'cv_mean_count_diff2023',
#  'cv_mean_count_difffeb',
#  'сх, лес, рыба',
#  'Добыча полезных ископаемых',
#  'Обрабатывающее произв',
#  'Электроэнергия, газ',
#  'Водоснаб',
#  'Строительство',
#  'Оптовая торговля',
#  'Траспорт',
#  'Общественное питание, гостиницы',
#  'Информация и связь',
#  'Финансы и страхование',
#  'Недвижимость',
#  'Наука и техника',
#  'администр',
#  'госуправление',
#  'образование',
#  'здравоохранение',
#  'культура и спорт',
#  'прочие',
#  'домохозяйства',
#  'excess_value_before',
#  'excess_value_after',
#  'dotation_2022',
#  'mean_unempl_days',
#  'mean_unempl_days_alltime',
#  'max_drop',
#  'sum_change',
#  'sum_drop',
#  'max_drop_manuf',
#  'sum_change_manuf',
#  'sum_drop_manuf',
#  'max_drop_power',
#  'sum_change_power',
#  'sum_drop_power',
#  'max_drop_water',
#  'sum_change_water',
#  'sum_drop_water']

# %%
main_df_norm_scaled[['cv', 'vac_count']].corr()
# Out:
#                  cv  vac_count
# cv         1.000000  -0.233817
# vac_count -0.233817   1.000000

# %%
main_df_norm_scaled[['dotation_2022', 'mean_unempl_days_alltime','mean_living_subsid', 'subsidised_families_flat']].corr()
# Out:
#                           dotation_2022  mean_unempl_days_alltime  \
# dotation_2022                  1.000000                  0.434506
# mean_unempl_days_alltime       0.434506                  1.000000
# mean_living_subsid            -0.083059                 -0.011532
# subsidised_families_flat      -0.017076                  0.008788
#
#                           mean_living_subsid  subsidised_families_flat
# dotation_2022                      -0.083059                 -0.017076
# mean_unempl_days_alltime           -0.011532                  0.008788
# mean_living_subsid                  1.000000                 -0.026137
# subsidised_families_flat           -0.026137                  1.000000

# %%
main_df_norm_scaled[['poverty_ratio', 'indebted', 'income', 'salary','mean_living_subsid']].corr()
# Out:
#                     poverty_ratio  indebted    income    salary  \
# poverty_ratio            1.000000  0.438560  0.577298  0.043498
# indebted                 0.438560  1.000000  0.546751  0.100647
# income                   0.577298  0.546751  1.000000  0.080818
# salary                   0.043498  0.100647  0.080818  1.000000
# mean_living_subsid      -0.073845 -0.084711 -0.034913  0.818413
#
#                     mean_living_subsid
# poverty_ratio                -0.073845
# indebted                     -0.084711
# income                       -0.034913
# salary                        0.818413
# mean_living_subsid            1.000000

# %%
features = ['dobycha', 'torgovlya', 'sum_change_manuf', 'sum_drop_manuf', 'dotation_2022', 'vpk', 'border', 'forest', 'poverty_ratio', 'indebted', 'city_people']
coef, r = calc_OLS(main_df_norm_scaled, 'cv', features)
r
# Out:
# cv ~ 1 + dobycha+torgovlya+sum_change_manuf+sum_drop_manuf+dotation_2022+vpk+border+forest+poverty_ratio+indebted+city_people
# 'R²=.59, F(11, 65)=8.04, p<.001'

# %%
coef
# Out:
#              feature  coef_robust  std_err_robust  z_robust  p-value_robust  \
# 0            dobycha       0.0626           0.142     0.441           0.659
# 1          torgovlya      -0.3410           0.137    -2.484           0.013
# 2   sum_change_manuf      -0.3375           0.104    -3.240           0.001
# 3     sum_drop_manuf       0.2554           0.106     2.401           0.016
# 4      dotation_2022       0.1103           0.093     1.182           0.237
# 5                vpk       0.0101           0.094     0.107           0.914
# 6             border       0.1786           0.094     1.908           0.056
# 7             forest       0.0651           0.095     0.687           0.492
# 8      poverty_ratio      -0.3149           0.134    -2.355           0.019
# 9           indebted       0.3292           0.118     2.796           0.005
# 10       city_people       0.1743           0.107     1.633           0.103
#
#     CIL_robust  CIR_robust sig_robust    coef  std_err      z  p-value    CIL  \
# 0       -0.216       0.341             0.0794    0.144  0.551    0.581 -0.203
# 1       -0.610      -0.072         ** -0.3596    0.153 -2.350    0.019 -0.659
# 2       -0.542      -0.133        *** -0.3483    0.123 -2.828    0.005 -0.590
# 3        0.047       0.464         **  0.2740    0.103  2.661    0.008  0.072
# 4       -0.073       0.293             0.1203    0.075  1.614    0.107 -0.026
# 5       -0.174       0.194             0.0257    0.088  0.291    0.771 -0.148
# 6       -0.005       0.362          *  0.1828    0.112  1.631    0.103 -0.037
# 7       -0.121       0.251             0.0609    0.077  0.795    0.427 -0.089
# 8       -0.577      -0.053         ** -0.3287    0.163 -2.019    0.043 -0.648
# 9        0.098       0.560        ***  0.3260    0.115  2.847    0.004  0.102
# 10      -0.035       0.384             0.1920    0.110  1.741    0.082 -0.024
#
#       CIR  sig
# 0   0.362
# 1  -0.060   **
# 2  -0.107  ***
# 3   0.476  ***
# 4   0.266
# 5   0.199
# 6   0.403
# 7   0.211
# 8  -0.010   **
# 9   0.550  ***
# 10  0.408    *

# %%
features = ['cv']#, 'dobycha', 'torgovlya', 'sum_change_manuf', 'sum_drop_manuf', 'dotation_2022', 'vpk', 'border', 'forest']#, 'poverty_ratio', 'indebted']
coef, r = calc_OLS(main_df_norm_scaled, 'vac_count', features, rename_dict=vac_industry_dict)
print(r)
display(coef)
#coef.to_csv('cv_vac.csv')
# Out:
# vac_count ~ 1 + cv
# R²=.05, F(1, 75)=4.96, p=.029
#   feature  coef_robust  std_err_robust  z_robust  p-value_robust  CIL_robust  \
# 0      cv      -0.1792           0.099    -1.801           0.072      -0.374
#
#    CIR_robust sig_robust    coef  std_err      z  p-value   CIL    CIR sig
# 0       0.016          * -0.2338    0.105 -2.227    0.026 -0.44 -0.028  **

# %%
features = ['cv', 'economic_growth', 'gossluz', 'income', 'internet', 'migration',
            'dobycha', 'torgovlya', 'sum_change_manuf', 'sum_drop_manuf', 'dotation_2022', 'vpk', 'border', 'forest', 'poverty_ratio', 'indebted']
coef, r = calc_OLS(main_df_norm_scaled, 'weddings', features, rename_dict=vac_industry_dict)
print(r)
display(coef)
# Out:
# weddings ~ 1 + cv+economic_growth+gossluz+income+internet+migration+dobycha+torgovlya+sum_change_manuf+sum_drop_manuf+dotation_2022+vpk+border+forest+poverty_ratio+indebted
# R²=.62, F(16, 43)=7.36, p<.001
#              feature  coef_robust  std_err_robust  z_robust  p-value_robust  \
# 0                 cv       0.1351           0.128     1.057           0.291
# 1    economic_growth      -0.2480           0.074    -3.344           0.001
# 2            gossluz       0.2882           0.104     2.766           0.006
# 3             income      -0.1275           0.119    -1.069           0.285
# 4           internet       0.0156           0.095     0.164           0.869
# 5          migration      -0.0467           0.090    -0.521           0.602
# 6            dobycha       0.2350           0.128     1.835           0.067
# 7          torgovlya       0.1405           0.144     0.976           0.329
# 8   sum_change_manuf      -0.0759           0.104    -0.730           0.466
# 9     sum_drop_manuf       0.0472           0.108     0.437           0.662
# 10     dotation_2022       0.1101           0.140     0.786           0.432
# 11               vpk      -0.0158           0.094    -0.167           0.867
# 12            border       0.0259           0.092     0.281           0.779
# 13            forest      -0.0132           0.086    -0.153           0.879
# 14     poverty_ratio      -0.1568           0.147    -1.068           0.285
# 15          indebted       0.3169           0.143     2.209           0.027
#
#     CIL_robust  CIR_robust sig_robust    coef  std_err      z  p-value    CIL  \
# 0       -0.115       0.385             0.0456    0.140  0.327    0.744 -0.228
# 1       -0.393      -0.103        *** -0.3142    0.128 -2.456    0.014 -0.565
# 2        0.084       0.492        ***  0.3260    0.107  3.043    0.002  0.116
# 3       -0.361       0.106            -0.1958    0.124 -1.574    0.116 -0.440
# 4       -0.171       0.202             0.0874    0.119  0.734    0.463 -0.146
# 5       -0.222       0.129            -0.0387    0.059 -0.652    0.514 -0.155
# 6       -0.016       0.486          *  0.2669    0.155  1.724    0.085 -0.037
# 7       -0.142       0.423             0.2210    0.135  1.635    0.102 -0.044
# 8       -0.280       0.128            -0.1235    0.135 -0.916    0.360 -0.388
# 9       -0.164       0.259             0.0621    0.087  0.714    0.475 -0.108
# 10      -0.165       0.385             0.1831    0.160  1.148    0.251 -0.130
# 11      -0.201       0.169            -0.0082    0.132 -0.062    0.951 -0.267
# 12      -0.155       0.207             0.0283    0.069  0.409    0.682 -0.107
# 13      -0.182       0.156             0.0420    0.140  0.299    0.765 -0.233
# 14      -0.445       0.131            -0.2466    0.211 -1.169    0.242 -0.660
# 15       0.036       0.598         **  0.4364    0.176  2.484    0.013  0.092
#
#       CIR  sig
# 0   0.319
# 1  -0.063   **
# 2   0.536  ***
# 3   0.048
# 4   0.321
# 5   0.078
# 6   0.570    *
# 7   0.486
# 8   0.141
# 9   0.233
# 10  0.496
# 11  0.251
# 12  0.164
# 13  0.317
# 14  0.167
# 15  0.781   **

# %% [markdown]
# # misc

# %%
vac_industry_dict

# %%
features = [f'ind{i}' for i in range(37)]
coef, r = calc_OLS(main_df_norm_scaled, 'cv', features, rename_dict=vac_industry_dict)
print(r)
display(coef)
coef.to_csv('cv_vac.csv')
# Out:
# cv ~ 1 + ind0+ind1+ind2+ind3+ind4+ind5+ind6+ind7+ind8+ind9+ind10+ind11+ind12+ind13+ind14+ind15+ind16+ind17+ind18+ind19+ind20+ind21+ind22+ind23+ind24+ind25+ind26+ind27+ind28+ind29+ind30+ind31+ind32+ind33+ind34+ind35+ind36
# R²=.71, F(36, 40)=80.23, p<.001
#                                               feature  coef_robust  \
# 0                                        Производство      -0.3537
# 1            Здравоохранение и социальное обеспечение       0.0409
# 2                                  Образование, наука       0.4499
# 3               Продажи, закупки, снабжение, торговля       0.1637
# 4        Транспорт, автобизнес, логистика, склад, ВЭД       0.2331
# 5                              Пищевая промышленность       0.0693
# 6                                   ЖКХ, эксплуатация      -0.0892
# 7   Строительство, ремонт, стройматериалы, недвижи...      -0.0172
# 8     Консалтинг, стратегическое развитие, управление      -0.0392
# 9           Сельское хозяйство, экология, ветеринария       0.1583
# 10                  Работы, не требующие квалификации      -0.3854
# 11                                      Юриспруденция       0.1605
# 12                              Рабочие специальности       0.2210
# 13  Информационные технологии, телекоммуникации, с...      -0.0794
# 14                                  Электроэнергетика      -0.2541
# 15                          Добывающая промышленность       0.2613
# 16                  Искусство, культура и развлечения       0.1750
# 17                                     Машиностроение      -0.0792
# 18  Банки, кредит, страхование, пенсионное обеспеч...      -0.2089
# 19                      Металлургия, металлообработка       0.0113
# 20  Государственная служба, некоммерческие организ...       0.0948
# 21  Лесная, деревообрабатывающая, целлюлозно-бумаж...       0.1301
# 22                        Безопасность, службы охраны       0.0864
# 23          Административная работа, секретариат, АХО      -0.0254
# 24                       Туризм, гостиницы, рестораны      -0.0389
# 25           Бухгалтерия, налоги, управленческий учет      -0.5392
# 26                             Маркетинг, реклама, PR      -0.1516
# 27           Услуги населению, сервисное обслуживание      -0.0751
# 28  Химическая, нефтехимическая, топливная промышл...      -0.2298
# 29                              Легкая промышленность      -0.0068
# 30                      Спорт, фитнес, салоны красоты       0.1660
# 31             Кадровая служба, управление персоналом      -0.0735
# 32                                  Высший менеджмент       0.5064
# 33                                  Домашний персонал       0.0734
# 34                                           Плотники       0.2515
# 35                   Лес и лесозаготовительные работы      -1.4904
# 36                  Деревообрабатывающее производство       1.3025
#
#     std_err_robust  z_robust  p-value_robust  CIL_robust  CIR_robust  \
# 0            0.077    -4.613           0.000      -0.504      -0.203
# 1            0.076     0.535           0.593      -0.109       0.191
# 2            0.126     3.562           0.000       0.202       0.697
# 3            0.104     1.578           0.115      -0.040       0.367
# 4            0.128     1.816           0.069      -0.018       0.485
# 5            0.092     0.757           0.449      -0.110       0.249
# 6            0.112    -0.797           0.426      -0.309       0.130
# 7            0.116    -0.148           0.882      -0.245       0.210
# 8            0.112    -0.350           0.726      -0.259       0.180
# 9            0.086     1.832           0.067      -0.011       0.328
# 10           0.129    -2.988           0.003      -0.638      -0.133
# 11           0.079     2.035           0.042       0.006       0.315
# 12           0.118     1.877           0.060      -0.010       0.452
# 13           0.083    -0.962           0.336      -0.241       0.082
# 14           0.090    -2.823           0.005      -0.431      -0.078
# 15           0.076     3.453           0.001       0.113       0.410
# 16           0.134     1.302           0.193      -0.089       0.438
# 17           0.099    -0.802           0.422      -0.273       0.114
# 18           0.086    -2.443           0.015      -0.376      -0.041
# 19           0.090     0.125           0.900      -0.166       0.189
# 20           0.116     0.816           0.415      -0.133       0.323
# 21           0.077     1.690           0.091      -0.021       0.281
# 22           0.076     1.130           0.259      -0.063       0.236
# 23           0.097    -0.262           0.793      -0.215       0.164
# 24           0.093    -0.419           0.675      -0.221       0.143
# 25           0.179    -3.010           0.003      -0.890      -0.188
# 26           0.112    -1.348           0.178      -0.372       0.069
# 27           0.076    -0.989           0.323      -0.224       0.074
# 28           0.067    -3.428           0.001      -0.361      -0.098
# 29           0.068    -0.101           0.920      -0.139       0.125
# 30           0.106     1.559           0.119      -0.043       0.375
# 31           0.103    -0.716           0.474      -0.275       0.128
# 32           0.209     2.419           0.016       0.096       0.917
# 33           0.064     1.151           0.250      -0.052       0.198
# 34           0.153     1.646           0.100      -0.048       0.551
# 35           0.687    -2.170           0.030      -2.837      -0.144
# 36           0.642     2.028           0.043       0.043       2.562
#
#    sig_robust    coef  std_err      z  p-value    CIL    CIR  sig
# 0        **** -0.4044    0.149 -2.705    0.007 -0.697 -0.111  ***
# 1              0.0682    0.143  0.477    0.633 -0.212  0.349
# 2        ****  0.4840    0.222  2.179    0.029  0.049  0.919   **
# 3              0.2303    0.147  1.566    0.117 -0.058  0.519
# 4           *  0.2238    0.245  0.913    0.361 -0.257  0.705
# 5              0.0246    0.182  0.135    0.892 -0.333  0.382
# 6             -0.0622    0.159 -0.392    0.695 -0.373  0.249
# 7             -0.0481    0.200 -0.240    0.810 -0.440  0.344
# 8              0.0919    0.208  0.442    0.659 -0.316  0.500
# 9           *  0.1249    0.146  0.856    0.392 -0.161  0.411
# 10        *** -0.3223    0.234 -1.379    0.168 -0.780  0.136
# 11         **  0.1655    0.133  1.241    0.215 -0.096  0.427
# 12          *  0.2116    0.161  1.314    0.189 -0.104  0.527
# 13            -0.0992    0.126 -0.785    0.433 -0.347  0.149
# 14        *** -0.2187    0.098 -2.230    0.026 -0.411 -0.026   **
# 15        ***  0.2246    0.094  2.398    0.016  0.041  0.408   **
# 16             0.0935    0.245  0.382    0.703 -0.387  0.574
# 17            -0.1398    0.176 -0.793    0.428 -0.486  0.206
# 18         ** -0.2153    0.199 -1.080    0.280 -0.606  0.175
# 19             0.0462    0.135  0.343    0.732 -0.218  0.310
# 20             0.1105    0.161  0.686    0.493 -0.205  0.426
# 21          *  0.0494    0.139  0.355    0.723 -0.224  0.323
# 22             0.0513    0.111  0.461    0.645 -0.167  0.269
# 23             0.0252    0.174  0.145    0.885 -0.315  0.365
# 24            -0.0705    0.162 -0.437    0.662 -0.387  0.246
# 25        *** -0.3954    0.291 -1.357    0.175 -0.967  0.176
# 26            -0.1930    0.296 -0.653    0.514 -0.772  0.387
# 27            -0.0852    0.133 -0.642    0.521 -0.345  0.175
# 28        *** -0.1375    0.112 -1.224    0.221 -0.358  0.083
# 29            -0.0231    0.091 -0.253    0.800 -0.202  0.156
# 30             0.1479    0.153  0.966    0.334 -0.152  0.448
# 31            -0.1657    0.152 -1.093    0.274 -0.463  0.131
# 32         **  0.4251    0.469  0.906    0.365 -0.494  1.345
# 33             0.0653    0.057  1.140    0.254 -0.047  0.178
# 34             0.2313    0.239  0.969    0.332 -0.236  0.699
# 35         ** -1.6087    1.244 -1.293    0.196 -4.048  0.830
# 36         **  1.4310    1.184  1.208    0.227 -0.890  3.752

# %%
# Out:
#   feature  coef_robust  std_err_robust  z_robust  p-value_robust  CIL_robust  \
# 0    ind0       -0.165           0.101    -1.633           0.102      -0.363
#
#    CIR_robust sig_robust    coef  std_err      z  p-value    CIL    CIR sig
# 0       0.033            -0.2338    0.123 -1.899    0.058 -0.475  0.008   *

# %%
main_df_norm_scaled[['poverty_ratio', 'indebted']].corr()

# %%
features = ['dobycha', 'torgovlya', 'sum_change_manuf', 'sum_drop_manuf', 'dotation_2022', 'vpk', 'border', 'forest', 'poverty_ratio', 'indebted', 'city_people']

f = 'cv ~ 1 + ' + ' + '.join(features)
print(f)
ols = smf.ols(f, main_df_norm_scaled).fit(cov_type='HC1')
print(ols.summary())

robust = smf.rlm(f, main_df_norm_scaled, M=sm.robust.norms.HuberT()).fit()
print(robust.summary())
# Out:
# cv ~ 1 + dobycha + torgovlya + sum_change_manuf + sum_drop_manuf + sum_change + dotation_2022 + vpk + border + forest + poverty_ratio + indebted + city_people
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     cv   R-squared:                       0.591
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     7.707
# Date:                Fri, 24 Mar 2023   Prob (F-statistic):           1.31e-08
# Time:                        00:43:44   Log-Likelihood:                -74.876
# No. Observations:                  77   AIC:                             175.8
# Df Residuals:                      64   BIC:                             206.2
# Df Model:                          12
# Covariance Type:                  HC1
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept         3.165e-16      0.080   3.96e-15      1.000      -0.157       0.157
# dobycha              0.0816      0.144      0.567      0.571      -0.201       0.364
# torgovlya           -0.3218      0.173     -1.865      0.062      -0.660       0.016
# sum_change_manuf    -0.3813      0.138     -2.756      0.006      -0.653      -0.110
# sum_drop_manuf       0.2761      0.108      2.546      0.011       0.064       0.489
# sum_change           0.0788      0.115      0.683      0.495      -0.148       0.305
# dotation_2022        0.1082      0.075      1.451      0.147      -0.038       0.254
# vpk                  0.0207      0.091      0.228      0.820      -0.158       0.199
# border               0.1702      0.113      1.502      0.133      -0.052       0.392
# forest               0.0545      0.076      0.717      0.473      -0.094       0.203
# poverty_ratio       -0.3597      0.182     -1.977      0.048      -0.716      -0.003
# indebted             0.3538      0.125      2.841      0.005       0.110       0.598
# city_people          0.1953      0.109      1.797      0.072      -0.018       0.408
# ==============================================================================
# Omnibus:                        0.265   Durbin-Watson:                   2.408
# Prob(Omnibus):                  0.876   Jarque-Bera (JB):                0.024
# Skew:                          -0.014   Prob(JB):                        0.988
# Kurtosis:                       3.081   Cond. No.                         4.14
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:                     cv   No. Observations:                   77
# Model:                            RLM   Df Residuals:                       64
# Method:                          IRLS   Df Model:                           12
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Fri, 24 Mar 2023
# Time:                        00:43:44
# No. Iterations:                    33
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0029      0.081     -0.036      0.971      -0.161       0.155
# dobycha              0.0807      0.137      0.588      0.557      -0.188       0.350
# torgovlya           -0.2711      0.142     -1.910      0.056      -0.549       0.007
# sum_change_manuf    -0.4098      0.110     -3.730      0.000      -0.625      -0.194
# sum_drop_manuf       0.2869      0.103      2.788      0.005       0.085       0.489
# sum_change           0.1089      0.105      1.039      0.299      -0.096       0.314
# dotation_2022        0.0970      0.092      1.058      0.290      -0.083       0.277
# vpk                 -0.0091      0.091     -0.100      0.920      -0.188       0.170
# border               0.1784      0.092      1.937      0.053      -0.002       0.359
# forest               0.0606      0.092      0.658      0.511      -0.120       0.241
# poverty_ratio       -0.3698      0.136     -2.724      0.006      -0.636      -0.104
# indebted             0.3760      0.120      3.141      0.002       0.141       0.611
# city_people          0.1764      0.103      1.706      0.088      -0.026       0.379
# ====================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .

# %%
calc_OLS(ols)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-a5a95509e5a5> in <module>
# ----> 1 calc_OLS(ols)
#
# TypeError: calc_OLS() missing 2 required positional arguments: 'x' and 'y'

# %%
base_ols = pd.read_html(ols.summary().tables[1].as_html(), header=0, index_col=0)[0].rename(columns={'P>|z|' : 'p-value',
                                                                            'std err' : 'std_err',
                                                                            '[0.025' : 'CI_l',
                                                                            '0.975]' : 'CI_r'})
base_ols['sig'] = [get_stars(i) for i in base_ols['p-value']]

robust_ols = pd.read_html(robust.summary().tables[1].as_html(), header=0, index_col=0)[0].rename(columns={'P>|z|' : 'p-value',
                                                                            'std err' : 'std_err',
                                                                            '[0.025' : 'CI_l',
                                                                            '0.975]' : 'CI_r'})
robust_ols['sig'] = [get_stars(i) for i in robust_ols['p-value']]
robust_ols = feats.drop(['p-value', 'sig'], axis=1).set_index('feature').join(robust_ols, how='left')
robust_ols.columns = [i+'_robust' for i in robust_ols.columns]

results = robust_ols.join(base_ols, how='left')
results

# %%
features = ['city_people', 'salary', 'migration', 'dotation_2022', 'indebted',
            'sum_drop_manuf', 'vpk', 'border']
            #'forest', 'auto', 'sum_change_manuf',

f = 'cv_mean_count_diff2022 ~ 1 + ' + ' + '.join(features)
print(f)
ols = smf.ols(f, main_df_norm_scaled).fit(cov_type='HC1')
print(ols.summary())

robust = smf.rlm(f, main_df_norm_scaled, M=sm.robust.norms.HuberT()).fit()
print(robust.summary())
# Out:
# cv_mean_count_diff2022 ~ 1 + city_people + salary + migration + dotation_2022 + indebted + sum_drop_manuf + vpk + border
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     cv_mean_count_diff2022   R-squared:                       0.476
# Model:                                OLS   Adj. R-squared:                  0.414
# Method:                     Least Squares   F-statistic:                     7.642
# Date:                    Thu, 23 Mar 2023   Prob (F-statistic):           3.07e-07
# Time:                            21:46:41   Log-Likelihood:                -84.372
# No. Observations:                      77   AIC:                             186.7
# Df Residuals:                          68   BIC:                             207.8
# Df Model:                               8
# Covariance Type:                      HC1
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       3.062e-16      0.088   3.49e-15      1.000      -0.172       0.172
# city_people       -0.1643      0.076     -2.163      0.031      -0.313      -0.015
# salary            -0.0467      0.034     -1.365      0.172      -0.114       0.020
# migration          0.0353      0.126      0.280      0.780      -0.212       0.283
# dotation_2022     -0.1379      0.056     -2.466      0.014      -0.248      -0.028
# indebted           0.3704      0.114      3.236      0.001       0.146       0.595
# sum_drop_manuf     0.1591      0.088      1.810      0.070      -0.013       0.331
# vpk                0.2956      0.090      3.297      0.001       0.120       0.471
# border             0.3116      0.149      2.095      0.036       0.020       0.603
# ==============================================================================
# Omnibus:                       17.849   Durbin-Watson:                   2.079
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.156
# Skew:                           0.944   Prob(JB):                     2.09e-06
# Kurtosis:                       5.141   Cond. No.                         2.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#                       Robust linear Model Regression Results
# ==================================================================================
# Dep. Variable:     cv_mean_count_diff2022   No. Observations:                   77
# Model:                                RLM   Df Residuals:                       68
# Method:                              IRLS   Df Model:                            8
# Norm:                              HuberT
# Scale Est.:                           mad
# Cov Type:                              H1
# Date:                    Thu, 23 Mar 2023
# Time:                            21:46:41
# No. Iterations:                        23
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -0.0817      0.069     -1.186      0.236      -0.217       0.053
# city_people       -0.1338      0.090     -1.490      0.136      -0.310       0.042
# salary            -0.0342      0.070     -0.490      0.624      -0.171       0.103
# migration          0.0042      0.089      0.047      0.962      -0.171       0.179
# dotation_2022     -0.1547      0.072     -2.137      0.033      -0.297      -0.013
# indebted           0.2598      0.077      3.363      0.001       0.108       0.411
# sum_drop_manuf     0.1814      0.075      2.406      0.016       0.034       0.329
# vpk                0.2811      0.075      3.756      0.000       0.134       0.428
# border             0.1965      0.070      2.793      0.005       0.059       0.334
# ==================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .

# %%
features = ['city_people', 'salary', 'migration', 'dotation_2022', 'indebted',
            'sum_change_manuf', 'sum_drop_manuf', 'forest', 'auto', 'vpk', 'border']

f = 'cv_mean_count_diff2023 ~ 1 + ' + ' + '.join(features)
print(f)
ols = smf.ols(f, main_df_norm_scaled).fit(cov_type='HC1')
print(ols.summary())

robust = smf.rlm(f, main_df_norm_scaled, M=sm.robust.norms.HuberT()).fit()
print(robust.summary())
# Out:
# cv_mean_count_diff2023 ~ 1 + city_people + salary + migration + dotation_2022 + indebted + sum_change_manuf + sum_drop_manuf + forest + auto + vpk + border
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     cv_mean_count_diff2023   R-squared:                       0.506
# Model:                                OLS   Adj. R-squared:                  0.423
# Method:                     Least Squares   F-statistic:                     5.818
# Date:                    Thu, 23 Mar 2023   Prob (F-statistic):           1.82e-06
# Time:                            21:46:46   Log-Likelihood:                -82.096
# No. Observations:                      77   AIC:                             188.2
# Df Residuals:                          65   BIC:                             216.3
# Df Model:                              11
# Covariance Type:                      HC1
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept         1.821e-16      0.087   2.09e-15      1.000      -0.171       0.171
# city_people         -0.2210      0.082     -2.693      0.007      -0.382      -0.060
# salary              -0.0309      0.034     -0.914      0.360      -0.097       0.035
# migration           -0.0011      0.111     -0.010      0.992      -0.218       0.216
# dotation_2022       -0.2208      0.072     -3.059      0.002      -0.362      -0.079
# indebted             0.4018      0.105      3.828      0.000       0.196       0.608
# sum_change_manuf     0.0629      0.072      0.874      0.382      -0.078       0.204
# sum_drop_manuf       0.1943      0.102      1.897      0.058      -0.006       0.395
# forest              -0.0976      0.087     -1.126      0.260      -0.268       0.072
# auto                -0.0885      0.115     -0.769      0.442      -0.314       0.137
# vpk                  0.2893      0.097      2.990      0.003       0.100       0.479
# border               0.2565      0.136      1.881      0.060      -0.011       0.524
# ==============================================================================
# Omnibus:                       13.126   Durbin-Watson:                   2.110
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.418
# Skew:                           0.816   Prob(JB):                     0.000449
# Kurtosis:                       4.463   Cond. No.                         2.63
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#                       Robust linear Model Regression Results
# ==================================================================================
# Dep. Variable:     cv_mean_count_diff2023   No. Observations:                   77
# Model:                                RLM   Df Residuals:                       65
# Method:                              IRLS   Df Model:                           11
# Norm:                              HuberT
# Scale Est.:                           mad
# Cov Type:                              H1
# Date:                    Thu, 23 Mar 2023
# Time:                            21:46:46
# No. Iterations:                        20
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0505      0.079     -0.637      0.524      -0.206       0.105
# city_people         -0.1932      0.107     -1.807      0.071      -0.403       0.016
# salary              -0.0167      0.080     -0.207      0.836      -0.174       0.141
# migration           -0.0114      0.107     -0.106      0.915      -0.221       0.199
# dotation_2022       -0.2324      0.085     -2.728      0.006      -0.399      -0.065
# indebted             0.3436      0.091      3.771      0.000       0.165       0.522
# sum_change_manuf     0.0459      0.097      0.472      0.637      -0.145       0.237
# sum_drop_manuf       0.1896      0.099      1.917      0.055      -0.004       0.383
# forest              -0.0632      0.087     -0.725      0.468      -0.234       0.108
# auto                -0.0512      0.090     -0.568      0.570      -0.228       0.125
# vpk                  0.2961      0.091      3.260      0.001       0.118       0.474
# border               0.1810      0.082      2.201      0.028       0.020       0.342
# ====================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .

# %%
def next_possible_feature (X_npf, y_npf, current_features, ignore_features=[]):
    function_dict = {'predictor': [], 'r-squared':[], 'p-value':[]}
    for col in X_npf.columns:
        if col not in (current_features+ignore_features):
            selected_X = X_npf[current_features + [col]]
            model = sm.OLS(y_npf, sm.add_constant(selected_X)).fit(cov_type='HC3')
            y_preds = model.predict(sm.add_constant(selected_X))
            function_dict['predictor'].append(col)
            r2 = np.corrcoef(y_npf, y_preds)[0, 1]**2
            p = model.pvalues[col]
            function_dict['r-squared'].append(r2)
            function_dict['p-value'].append(p)
    function_df = pd.DataFrame(function_dict).sort_values(by=['r-squared'],\
                                                          ascending = False)
    #display(function_df)
    return function_df.iloc[0,0], function_df.iloc[0,1], function_df.iloc[0,2]

# %%
def get_stars(p):
    if p < 0.001:
        return '****'
    if p < 0.01:
        return '***'
    if p < 0.05:
        return '**'
    if p < 0.10:
        return '*'
    return ''

# %% [markdown]
# ## Безработица по материалам портала "Работа в России"

# %%
cols = [
    'economic_growth', 'excessive_voices', 'income',
       'vote_turnout', 'internet', 'city_people', #'rate_yes',
       'salary', 'migration', 'hospital', 'subsidii', 'zaderzania',  'mean_living_subsid',
       'antiwar_zaderzania', 'poverty_ratio', 'excess_value_before', 'excess_value_after',
       'max_drop', 'sum_change', 'sum_drop', 'max_drop_manuf',
       'sum_change_manuf', 'sum_drop_manuf', 'dotation_2022', 'mean_unempl_days', 'mean_unempl_days_alltime',
]

cols = [
    'city_people', 'salary', 'migration', 'hospital', 'subsidii', 'zaderzania',  'mean_living_subsid',
       'antiwar_zaderzania', 'poverty_ratio', 'excess_value_before', 'excess_value_after',
       'max_drop', 'sum_change', 'sum_drop', 'max_drop_manuf',
       'sum_change_manuf', 'sum_drop_manuf', 'dotation_2022', 'mean_unempl_days', 'mean_unempl_days_alltime',
       'forest', 'auto', 'vpk', 'border'
]
tmp = main_df_norm_scaled.dropna(subset=cols+['cv'])
X = tmp[cols]
y = tmp['cv']

# %%
selected_features = []
r_squared = []
p_value = []

while len(selected_features) != X.shape[1]:
  next_feat = next_possible_feature(X_npf=X, y_npf=y, current_features=selected_features)
  selected_features.append(next_feat[0])
  r_squared.append(next_feat[1])
  p_value.append(next_feat[2])

feats = pd.DataFrame({
    'feature': selected_features,
    'r_sq': r_squared,
    'p-value': np.round(p_value, 5),
    'sig': [get_stars(i) for i in p_value]
})

feats[['feature', 'r_sq']].plot()
# Out:
# <Axes: >

# %%
feats
# Out:
#                      feature      r_sq  p-value   sig
# 0                city_people  0.288856  0.00000  ****
# 1                 sum_change  0.352162  0.06893     *
# 2   mean_unempl_days_alltime  0.431516  0.57754
# 3                   subsidii  0.454865  0.33774
# 4              dotation_2022  0.486651  0.19106
# 5             max_drop_manuf  0.521055  0.14197
# 6                        vpk  0.537620  0.24124
# 7                     forest  0.555418  0.33280
# 8                   max_drop  0.561687  0.22490
# 9                   hospital  0.569907  0.46593
# 10                      auto  0.574740  0.54503
# 11                 migration  0.577855  0.87972
# 12        excess_value_after  0.582730  0.78052
# 13       excess_value_before  0.605533  0.30841
# 14                    salary  0.611375  0.91510
# 15        mean_living_subsid  0.680108  0.10442
# 16                zaderzania  0.691831  0.32743
# 17             poverty_ratio  0.695907  0.63298
# 18          mean_unempl_days  0.697301  0.74723
# 19            sum_drop_manuf  0.698360  0.83847
# 20                    border  0.699477  0.84033
# 21          sum_change_manuf  0.699672  0.90194
# 22                  sum_drop  0.699755  0.96291
# 23        antiwar_zaderzania  0.699755  0.56241

# %%
best_feats = feats.head(20).feature
f = 'cv ~ 1 + ' + ' + '.join(best_feats)
print(f)
ols = smf.ols(f, main_df_norm_scaled).fit(cov_type='HC1')
print(ols.summary())

robust = smf.rlm(f, main_df_norm_scaled, M=sm.robust.norms.HuberT()).fit() #TrimmedMean(0.5)
print(robust.summary())
# Out:
# cv ~ 1 + city_people + sum_change + mean_unempl_days_alltime + subsidii + dotation_2022 + max_drop_manuf + vpk + forest + max_drop + hospital + auto + migration + excess_value_after + excess_value_before + salary + mean_living_subsid + zaderzania + poverty_ratio + mean_unempl_days + sum_drop_manuf
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     cv   R-squared:                       0.698
# Model:                            OLS   Adj. R-squared:                  0.531
# Method:                 Least Squares   F-statistic:                     30.45
# Date:                Thu, 23 Mar 2023   Prob (F-statistic):           7.94e-17
# Time:                        17:49:31   Log-Likelihood:                -33.748
# No. Observations:                  57   AIC:                             109.5
# Df Residuals:                      36   BIC:                             152.4
# Df Model:                          20
# Covariance Type:                  HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.1054      0.098      1.070      0.285      -0.088       0.298
# city_people                  0.6281      0.260      2.412      0.016       0.118       1.138
# sum_change                   0.2618      0.120      2.187      0.029       0.027       0.496
# mean_unempl_days_alltime     0.0999      0.816      0.123      0.902      -1.499       1.699
# subsidii                     0.2350      0.183      1.285      0.199      -0.123       0.593
# dotation_2022                0.0872      0.094      0.927      0.354      -0.097       0.272
# max_drop_manuf               0.1507      0.229      0.657      0.511      -0.299       0.600
# vpk                         -0.0955      0.090     -1.058      0.290      -0.272       0.081
# forest                       0.0292      0.102      0.285      0.776      -0.171       0.230
# max_drop                    -0.0260      0.066     -0.391      0.696      -0.156       0.104
# hospital                     0.1477      0.114      1.293      0.196      -0.076       0.371
# auto                        -0.1589      0.094     -1.682      0.093      -0.344       0.026
# migration                    0.2826      0.127      2.217      0.027       0.033       0.532
# excess_value_after           0.5373      0.253      2.121      0.034       0.041       1.034
# excess_value_before         -0.5807      0.263     -2.206      0.027      -1.097      -0.065
# salary                       0.7046      0.178      3.961      0.000       0.356       1.053
# mean_living_subsid          -0.6621      0.171     -3.878      0.000      -0.997      -0.327
# zaderzania                  -0.1069      0.099     -1.076      0.282      -0.302       0.088
# poverty_ratio               -0.0866      0.150     -0.578      0.563      -0.380       0.207
# mean_unempl_days             0.3674      0.963      0.382      0.703      -1.520       2.255
# sum_drop_manuf              -0.0703      0.210     -0.335      0.737      -0.481       0.341
# ==============================================================================
# Omnibus:                        0.340   Durbin-Watson:                   2.305
# Prob(Omnibus):                  0.844   Jarque-Bera (JB):                0.385
# Skew:                           0.172   Prob(JB):                        0.825
# Kurtosis:                       2.792   Cond. No.                         28.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:                     cv   No. Observations:                   57
# Model:                            RLM   Df Residuals:                       36
# Method:                          IRLS   Df Model:                           20
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Thu, 23 Mar 2023
# Time:                        17:49:31
# No. Iterations:                    33
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.0886      0.096      0.919      0.358      -0.100       0.278
# city_people                  0.6014      0.274      2.197      0.028       0.065       1.138
# sum_change                   0.2528      0.109      2.318      0.020       0.039       0.467
# mean_unempl_days_alltime     0.1066      0.786      0.136      0.892      -1.434       1.648
# subsidii                     0.2744      0.214      1.285      0.199      -0.144       0.693
# dotation_2022                0.0751      0.120      0.625      0.532      -0.160       0.311
# max_drop_manuf               0.1655      0.227      0.731      0.465      -0.278       0.610
# vpk                         -0.0490      0.093     -0.526      0.599      -0.232       0.134
# forest                      -0.0100      0.099     -0.101      0.919      -0.203       0.183
# max_drop                    -0.0340      0.090     -0.377      0.706      -0.211       0.143
# hospital                     0.1997      0.154      1.297      0.194      -0.102       0.501
# auto                        -0.1977      0.094     -2.093      0.036      -0.383      -0.013
# migration                    0.3278      0.125      2.621      0.009       0.083       0.573
# excess_value_after           0.5543      0.245      2.262      0.024       0.074       1.035
# excess_value_before         -0.6134      0.258     -2.376      0.018      -1.120      -0.107
# salary                       0.7929      0.217      3.657      0.000       0.368       1.218
# mean_living_subsid          -0.7454      0.209     -3.558      0.000      -1.156      -0.335
# zaderzania                  -0.1479      0.114     -1.295      0.195      -0.372       0.076
# poverty_ratio               -0.0735      0.146     -0.503      0.615      -0.360       0.213
# mean_unempl_days             0.3741      0.929      0.403      0.687      -1.447       2.195
# sum_drop_manuf              -0.0664      0.199     -0.333      0.739      -0.457       0.324
# ============================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .

# %%
best_feats = ['city_people',# 'salary', 'migration', 'max_drop', 'sum_change', 'sum_drop', 'max_drop_manuf', 'dotation_2022',
       'sum_change_manuf', 'sum_drop_manuf', 'forest', 'auto', 'vpk', 'border']

best_feats = [
    'city_people', 'salary', 'migration', 'mean_living_subsid',
    'sum_change_manuf', 'sum_drop_manuf', 'dotation_2022',
       'forest', 'auto', 'vpk', 'border'
]

f = 'cv ~ 1 + ' + ' + '.join(best_feats)
#f = 'cv ~ 1 + sum_change_manuf + sum_drop_manuf +  auto * vpk'
print(f)
ols = smf.ols(f, main_df_norm_scaled).fit(cov_type='HC1')
print(ols.summary())

robust = smf.rlm(f, main_df_norm_scaled, M=sm.robust.norms.HuberT()).fit() #TrimmedMean(0.5)
print(robust.summary())
# Out:
# cv ~ 1 + city_people + salary + migration + mean_living_subsid + sum_change_manuf + sum_drop_manuf + dotation_2022 + forest + auto + vpk + border
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     cv   R-squared:                       0.301
# Model:                            OLS   Adj. R-squared:                  0.183
# Method:                 Least Squares   F-statistic:                     1.825
# Date:                Thu, 23 Mar 2023   Prob (F-statistic):             0.0674
# Time:                        17:53:32   Log-Likelihood:                -95.466
# No. Observations:                  77   AIC:                             214.9
# Df Residuals:                      65   BIC:                             243.1
# Df Model:                          11
# Covariance Type:                  HC1
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           3.165e-16      0.104   3.05e-15      1.000      -0.203       0.203
# city_people            0.4015      0.207      1.938      0.053      -0.004       0.807
# salary                 0.2269      0.217      1.045      0.296      -0.199       0.653
# migration              0.0234      0.262      0.089      0.929      -0.491       0.537
# mean_living_subsid    -0.2222      0.224     -0.990      0.322      -0.662       0.218
# sum_change_manuf      -0.4212      0.205     -2.050      0.040      -0.824      -0.019
# sum_drop_manuf         0.1940      0.226      0.859      0.391      -0.249       0.637
# dotation_2022          0.0653      0.136      0.479      0.632      -0.202       0.332
# forest                 0.2264      0.090      2.522      0.012       0.050       0.402
# auto                  -0.0681      0.092     -0.741      0.459      -0.248       0.112
# vpk                   -0.0450      0.102     -0.439      0.661      -0.246       0.156
# border                -0.0156      0.086     -0.182      0.856      -0.184       0.152
# ==============================================================================
# Omnibus:                        3.061   Durbin-Watson:                   2.075
# Prob(Omnibus):                  0.216   Jarque-Bera (JB):                2.966
# Skew:                          -0.015   Prob(JB):                        0.227
# Kurtosis:                       3.961   Cond. No.                         3.91
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:                     cv   No. Observations:                   77
# Model:                            RLM   Df Residuals:                       65
# Method:                          IRLS   Df Model:                           11
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Thu, 23 Mar 2023
# Time:                        17:53:32
# No. Iterations:                    50
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             -0.0238      0.094     -0.253      0.800      -0.208       0.160
# city_people            0.2119      0.122      1.731      0.083      -0.028       0.452
# salary                 0.1570      0.173      0.907      0.365      -0.182       0.496
# migration             -0.1680      0.128     -1.309      0.190      -0.420       0.083
# mean_living_subsid    -0.1934      0.177     -1.093      0.274      -0.540       0.153
# sum_change_manuf      -0.3839      0.117     -3.275      0.001      -0.614      -0.154
# sum_drop_manuf         0.2934      0.117      2.498      0.012       0.063       0.524
# dotation_2022          0.0055      0.102      0.054      0.957      -0.195       0.206
# forest                 0.2211      0.105      2.110      0.035       0.016       0.426
# auto                  -0.1018      0.107     -0.954      0.340      -0.311       0.107
# vpk                   -0.0881      0.107     -0.825      0.409      -0.297       0.121
# border                -0.0085      0.098     -0.087      0.930      -0.200       0.183
# ======================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .

# %%
base_ols = pd.read_html(ols.summary().tables[1].as_html(), header=0, index_col=0)[0].rename(columns={'P>|z|' : 'p-value',
                                                                            'std err' : 'std_err',
                                                                            '[0.025' : 'CI_l',
                                                                            '0.975]' : 'CI_r'})
base_ols['sig'] = [get_stars(i) for i in base_ols['p-value']]

robust_ols = pd.read_html(robust.summary().tables[1].as_html(), header=0, index_col=0)[0].rename(columns={'P>|z|' : 'p-value',
                                                                            'std err' : 'std_err',
                                                                            '[0.025' : 'CI_l',
                                                                            '0.975]' : 'CI_r'})
robust_ols['sig'] = [get_stars(i) for i in robust_ols['p-value']]
robust_ols = feats.drop(['p-value', 'sig'], axis=1).set_index('feature').join(robust_ols, how='left')
robust_ols.columns = [i+'_robust' for i in robust_ols.columns]

results = robust_ols.join(base_ols, how='left')
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-e8e1d9a9c579> in <module>
#      10                                                                             '0.975]' : 'CI_r'})
#      11 robust_ols['sig'] = [get_stars(i) for i in robust_ols['p-value']]
# ---> 12 robust_ols = feats.drop(['p-value', 'sig'], axis=1).set_index('feature').join(robust_ols, how='left')
#      13 robust_ols.columns = [i+'_robust' for i in robust_ols.columns]
#      14
#
# NameError: name 'feats' is not defined

# %%
#plt.rcParams["figure.figsize"] = (25, 20)
#fig = sm.graphics.plot_partregress_grid(robust)
#fig.tight_layout(pad=1.0)
#plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]

# %%
results[pd.notna(results['sig']) & (results['sig'] != '')]
# Out:
#          r_sq_robust  coef_robust  std_err_robust  z_robust  p-value_robust  \
# feature
# forest      0.555418       0.2506           0.097     2.585            0.01
#
#          CI_l_robust  CI_r_robust sig_robust    coef  std_err      z  p-value  \
# feature
# forest         0.061        0.441         **  0.2383    0.081  2.943    0.003
#
#          CI_l   CI_r  sig
# feature
# forest   0.08  0.397  ***

# %%
def tree_graph(r, title, robust=True):
    def addlabels(x, y, sig):
      for i, j in enumerate(x):
          if j < 0:
            j -= 0.1
          else:
            j += 0.05
          plt.text(j, y[i], sig[i])
    rb = '_robust' if robust else ''
    d = r[pd.notna(r['sig'+rb])]# & (r['sig'+rb] != '')]
    x1 = d[d['coef'+rb] < 0]['coef'+rb].to_list()
    sig1 = d[d['coef'+rb] < 0]['sig'+rb].to_list()
    x2 = d[d['coef'+rb] > 0]['coef'+rb].to_list()
    sig2 = d[d['coef'+rb] > 0]['sig'+rb].to_list()
    y1 = range(len(x1))
    y2 = range(len(x1), (len(x1) + len(x2)))
    y = range(len(x1) + len(x2))
    yl1 = d[d['coef'+rb] < 0].feature.to_list()
    yl2 = d[d['coef'+rb] > 0].feature.to_list()
    fig, axes = plt.subplots(ncols=2, sharey=True)
    bar1 = axes[0].barh(y1, x1, align='center', color='red')
    bar2 = axes[1].barh(y2, x2, align='center', color='blue')
    axes[0].set(yticks=y, yticklabels=yl1 + yl2)
    axes[0].set_xlim([-1, -0.001])
    axes[1].set_xlim([0.001, 1])
    for ax in axes.flat:
        ax.margins(0.03)
        ax.grid(True)
    for i, b in enumerate(bar1):
        if len(sig1[i]):
          b.set_color('mediumorchid')
        else:
          b.set_color('thistle')
    for i, b in enumerate(bar2):
        if len(sig2[i]):
          b.set_color('mediumorchid')
        else:
          b.set_color('thistle')

    '''
    ci1_l = d[d['coef'+rb] < 0]['coef'+rb] - d[d['coef'+rb] < 0]['CI_l'+rb]
    ci1_r = d[d['coef'+rb] < 0]['CI_r'+rb] - d[d['coef'+rb] < 0]['coef'+rb]
    xerr1 = [ci1_l.to_list(), ci1_r.to_list()]
    ci2_l = d[d['coef'+rb] > 0]['coef'+rb] - d[d['coef'+rb] > 0]['CI_l'+rb]
    ci2_r = d[d['coef'+rb] > 0]['CI_r'+rb] - d[d['coef'+rb] > 0]['coef'+rb]
    xerr2 = [ci2_l.to_list(), ci2_r.to_list()]
    axes[0].errorbar(x1, y1, xerr=xerr1,
        fmt='none',     # don't connect data points
        ecolor='black', # color of error lines
        elinewidth=1,   # width of error lines
        capsize=4,      # length of error caps
        zorder=-1,      # put error bars behind scatter points
    )
    axes[1].errorbar(x2, y2, xerr=xerr2,
        fmt='none',     # don't connect data points
        ecolor='black', # color of error lines
        elinewidth=1,   # width of error lines
        capsize=4,      # length of error caps
        zorder=-1,      # put error bars behind scatter points
    )
    '''
    addlabels(x1, y1, sig1)
    addlabels(x2, y2, sig2)
    axes[0].tick_params(axis='y', which='both', labelleft=True, labelright=False)
    axes[1].tick_params(axis='y', which='both', labelleft=False, labelright=False)
    fig.suptitle(title, x=0.63)
    #fig.text(0.63, 0, 'Стандартизованный коэффициент β', ha='center')
    fig.text(0.63, 0, 'Средний вклад на единицу изменения фактора (β)', ha='center')
    fig.tight_layout()
    fig.subplots_adjust(wspace=0, top=0.93)
    plt.show()

# %%
ren = {'city_people': 'Доля городского\nнаселения',
       'vote_turnout': 'Явка на голосование\n по поправкам',
       'internet': 'Доступ к интернету',
       'poverty_ratio': 'Доля бедного\nнаселения',
       'income': 'Располагаемые ресурсы\nдомохозяйства',
       'subsidii': 'Социальные выплаты\n населению',
       'excessive_voices': 'Избыточные голоса\nна выборах за ЕР',
       'zaderzania': 'Задержания\nна протестных акциях',
       }
r = results.copy().sort_values(by=['sig']).reset_index()
r['feature'] = r['feature'].apply(lambda x: ren[x] if x in ren else x)
#'Безработица по данным резюме портала "Работа в России" (OLS)'
tree_graph(r, robust=False, title='Влияние факторов на регистрируемую безработицу')
tree_graph(r, robust=True, title='Влияние факторов на регистрируемую безработицу (robust OLS)')

# %% [markdown]
# ## Мобилизация на данных избыточных свадеб

# %%
cols = ['economic_growth',
 'gossluz',
 'income',
 'vote_turnout',
 #'rate_yes',
 'internet',
 'city_people',
 'salary',
 'migration',
 #'hospital',
 'subsidii',
 'cv',
 #'indebted',
 'poverty_ratio',
 'zaderzania',
 'antiwar_zaderzania',
 'subsidii_flat',
 'subsidised_families_flat',
 'excess_value_before', 'excess_value_after']
tmp = main_df_norm_scaled.dropna(subset=cols + ['weddings'])
X = tmp[cols]
y = tmp['weddings']

# %%
main_df_norm_scaled.dropna(subset=cols + ['weddings'])[['subsidii_flat', 'indebted', 'income']].corr()
# Out:
#                subsidii_flat  indebted    income
# subsidii_flat       1.000000  0.199599  0.313958
# indebted            0.199599  1.000000  0.740418
# income              0.313958  0.740418  1.000000

# %%
selected_features = []
r_squared = []
p_value = []

while len(selected_features) != X.shape[1]:
  next_feat = next_possible_feature(X_npf=X, y_npf=y, current_features=selected_features)
  selected_features.append(next_feat[0])
  r_squared.append(next_feat[1])
  p_value.append(next_feat[2])

feats = pd.DataFrame({
    'feature': selected_features,
    'r_sq': r_squared,
    'p-value': np.round(p_value, 5),
    'sig': [get_stars(i) for i in p_value]
})

feats[['feature', 'r_sq']].plot()
# Out:
# <AxesSubplot:>

# %%
feats
# Out:
#                      feature      r_sq  p-value  sig
# 0            economic_growth  0.215983  0.10669
# 1                         cv  0.308470  0.02917   **
# 2                    gossluz  0.334714  0.17884
# 3                     income  0.377174  0.00770  ***
# 4                   internet  0.398053  0.39650
# 5                  migration  0.421448  0.35926
# 6              subsidii_flat  0.453185  0.13272
# 7   subsidised_families_flat  0.464058  0.70159
# 8                     salary  0.487887  0.48919
# 9                   subsidii  0.494613  0.76783
# 10              vote_turnout  0.498755  0.54524
# 11        excess_value_after  0.501679  0.73052
# 12       excess_value_before  0.504832  0.73814
# 13             poverty_ratio  0.509066  0.62156
# 14                zaderzania  0.509635  0.86630
# 15               city_people  0.509886  0.93288
# 16        antiwar_zaderzania  0.509886  0.87895

# %%
best_feats = feats.head(8).feature
f = 'weddings ~ 1 + ' + ' + '.join(best_feats)
print(f)
ols = smf.ols(f, main_df_norm_scaled).fit(cov_type='HC1')
print(ols.summary())

robust = smf.rlm(f, main_df_norm_scaled, M=sm.robust.norms.HuberT()).fit() #TrimmedMean(0.5)
print(robust.summary())
# Out:
# weddings ~ 1 + economic_growth + cv + gossluz + income + internet + migration + subsidii_flat + subsidised_families_flat
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               weddings   R-squared:                       0.497
# Model:                            OLS   Adj. R-squared:                  0.423
# Method:                 Least Squares   F-statistic:                     13.25
# Date:                Sun, 26 Feb 2023   Prob (F-statistic):           2.29e-10
# Time:                        19:45:20   Log-Likelihood:                -67.728
# No. Observations:                  63   AIC:                             153.5
# Df Residuals:                      54   BIC:                             172.7
# Df Model:                           8
# Covariance Type:                  HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.0533      0.121     -0.442      0.658      -0.290       0.183
# economic_growth             -0.4066      0.159     -2.560      0.010      -0.718      -0.095
# cv                           0.3247      0.152      2.137      0.033       0.027       0.623
# gossluz                      0.4369      0.107      4.082      0.000       0.227       0.647
# income                      -0.0865      0.108     -0.797      0.425      -0.299       0.126
# internet                     0.0214      0.126      0.170      0.865      -0.225       0.268
# migration                   -0.2465      0.085     -2.907      0.004      -0.413      -0.080
# subsidii_flat               -0.8632      0.611     -1.412      0.158      -2.062       0.335
# subsidised_families_flat     0.3251      0.707      0.460      0.646      -1.060       1.710
# ==============================================================================
# Omnibus:                       23.012   Durbin-Watson:                   1.882
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.229
# Skew:                           1.246   Prob(JB):                     1.84e-09
# Kurtosis:                       6.019   Cond. No.                         10.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:               weddings   No. Observations:                   63
# Model:                            RLM   Df Residuals:                       54
# Method:                          IRLS   Df Model:                            8
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Sun, 26 Feb 2023
# Time:                        19:45:21
# No. Iterations:                    35
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.1672      0.087     -1.912      0.056      -0.339       0.004
# economic_growth             -0.2622      0.077     -3.402      0.001      -0.413      -0.111
# cv                           0.4136      0.128      3.226      0.001       0.162       0.665
# gossluz                      0.3867      0.127      3.034      0.002       0.137       0.637
# income                      -0.0309      0.084     -0.367      0.714      -0.196       0.134
# internet                    -0.0146      0.093     -0.156      0.876      -0.197       0.168
# migration                   -0.2054      0.110     -1.866      0.062      -0.421       0.010
# subsidii_flat               -0.1912      0.431     -0.443      0.657      -1.036       0.654
# subsidised_families_flat    -0.4162      0.453     -0.919      0.358      -1.304       0.471
# ============================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .

# %%
best_feats = cols = ['city_people',# 'salary', 'migration', 'max_drop', 'sum_change', 'sum_drop', 'max_drop_manuf', 'dotation_2022',
       'sum_change_manuf', 'sum_drop_manuf', 'forest', 'auto', 'vpk', 'border']
f = 'weddings ~ 1 + ' + ' + '.join(best_feats)
print(f)
ols = smf.ols(f, main_df_norm_scaled).fit(cov_type='HC1')
print(ols.summary())

robust = smf.rlm(f, main_df_norm_scaled, M=sm.robust.norms.HuberT()).fit() #TrimmedMean(0.5)
print(robust.summary())
# Out:
# weddings ~ 1 + city_people + sum_change_manuf + sum_drop_manuf + forest + auto + vpk + border
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               weddings   R-squared:                       0.199
# Model:                            OLS   Adj. R-squared:                  0.091
# Method:                 Least Squares   F-statistic:                     5.975
# Date:                Thu, 23 Mar 2023   Prob (F-statistic):           3.94e-05
# Time:                        17:42:13   Log-Likelihood:                -78.485
# No. Observations:                  60   AIC:                             173.0
# Df Residuals:                      52   BIC:                             189.7
# Df Model:                           7
# Covariance Type:                  HC1
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0380      0.125     -0.305      0.760      -0.282       0.206
# city_people          0.3369      0.071      4.745      0.000       0.198       0.476
# sum_change_manuf    -0.1570      0.132     -1.193      0.233      -0.415       0.101
# sum_drop_manuf      -0.0543      0.068     -0.798      0.425      -0.188       0.079
# forest               0.1301      0.139      0.938      0.348      -0.142       0.402
# auto                -0.1394      0.077     -1.802      0.071      -0.291       0.012
# vpk                 -0.0009      0.148     -0.006      0.995      -0.292       0.290
# border              -0.0445      0.051     -0.881      0.379      -0.144       0.055
# ==============================================================================
# Omnibus:                       32.754   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               64.923
# Skew:                           1.830   Prob(JB):                     7.98e-15
# Kurtosis:                       6.546   Cond. No.                         2.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:               weddings   No. Observations:                   60
# Model:                            RLM   Df Residuals:                       52
# Method:                          IRLS   Df Model:                            7
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Thu, 23 Mar 2023
# Time:                        17:42:13
# No. Iterations:                    30
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.2212      0.076     -2.920      0.004      -0.370      -0.073
# city_people          0.3701      0.070      5.273      0.000       0.233       0.508
# sum_change_manuf    -0.1957      0.101     -1.942      0.052      -0.393       0.002
# sum_drop_manuf       0.0080      0.088      0.091      0.927      -0.165       0.181
# forest               0.1039      0.074      1.403      0.161      -0.041       0.249
# auto                -0.0903      0.083     -1.088      0.277      -0.253       0.072
# vpk                  0.0157      0.084      0.186      0.853      -0.150       0.181
# border               0.0058      0.077      0.075      0.940      -0.145       0.156
# ====================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .

# %%
base_ols = pd.read_html(ols.summary().tables[1].as_html(), header=0, index_col=0)[0].rename(columns={'P>|z|' : 'p-value',
                                                                            'std err' : 'std_err',
                                                                            '[0.025' : 'CI_l',
                                                                            '0.975]' : 'CI_r'})
base_ols['sig'] = [get_stars(i) for i in base_ols['p-value']]

robust_ols = pd.read_html(robust.summary().tables[1].as_html(), header=0, index_col=0)[0].rename(columns={'P>|z|' : 'p-value',
                                                                            'std err' : 'std_err',
                                                                            '[0.025' : 'CI_l',
                                                                            '0.975]' : 'CI_r'})
robust_ols['sig'] = [get_stars(i) for i in robust_ols['p-value']]
robust_ols = feats.drop(['p-value', 'sig'], axis=1).set_index('feature').join(robust_ols, how='left')
robust_ols.columns = [i+'_robust' for i in robust_ols.columns]

results = robust_ols.join(base_ols, how='left')
results
# Out:
#                           r_sq_robust  coef_robust  std_err_robust  z_robust  \
# feature
# city_people                  0.288856       0.3701           0.070     5.273
# sum_change                   0.352162          NaN             NaN       NaN
# mean_unempl_days_alltime     0.431516          NaN             NaN       NaN
# subsidii                     0.454865          NaN             NaN       NaN
# dotation_2022                0.486651          NaN             NaN       NaN
# max_drop_manuf               0.521055          NaN             NaN       NaN
# vpk                          0.537620       0.0157           0.084     0.186
# forest                       0.555418       0.1039           0.074     1.403
# max_drop                     0.561687          NaN             NaN       NaN
# hospital                     0.569907          NaN             NaN       NaN
# auto                         0.574740      -0.0903           0.083    -1.088
# migration                    0.577855          NaN             NaN       NaN
# excess_value_after           0.582730          NaN             NaN       NaN
# excess_value_before          0.605533          NaN             NaN       NaN
# salary                       0.611375          NaN             NaN       NaN
# mean_living_subsid           0.680108          NaN             NaN       NaN
# zaderzania                   0.691831          NaN             NaN       NaN
# poverty_ratio                0.695907          NaN             NaN       NaN
# mean_unempl_days             0.697301          NaN             NaN       NaN
# sum_drop_manuf               0.698360       0.0080           0.088     0.091
# sum_drop                     0.698718          NaN             NaN       NaN
# sum_change_manuf             0.698902      -0.1957           0.101    -1.942
# antiwar_zaderzania           0.698902          NaN             NaN       NaN
#
#                           p-value_robust  CI_l_robust  CI_r_robust sig_robust  \
# feature
# city_people                        0.000        0.233        0.508       ****
# sum_change                           NaN          NaN          NaN        NaN
# mean_unempl_days_alltime             NaN          NaN          NaN        NaN
# subsidii                             NaN          NaN          NaN        NaN
# dotation_2022                        NaN          NaN          NaN        NaN
# max_drop_manuf                       NaN          NaN          NaN        NaN
# vpk                                0.853       -0.150        0.181
# forest                             0.161       -0.041        0.249
# max_drop                             NaN          NaN          NaN        NaN
# hospital                             NaN          NaN          NaN        NaN
# auto                               0.277       -0.253        0.072
# migration                            NaN          NaN          NaN        NaN
# excess_value_after                   NaN          NaN          NaN        NaN
# excess_value_before                  NaN          NaN          NaN        NaN
# salary                               NaN          NaN          NaN        NaN
# mean_living_subsid                   NaN          NaN          NaN        NaN
# zaderzania                           NaN          NaN          NaN        NaN
# poverty_ratio                        NaN          NaN          NaN        NaN
# mean_unempl_days                     NaN          NaN          NaN        NaN
# sum_drop_manuf                     0.927       -0.165        0.181
# sum_drop                             NaN          NaN          NaN        NaN
# sum_change_manuf                   0.052       -0.393        0.002          *
# antiwar_zaderzania                   NaN          NaN          NaN        NaN
#
#                             coef  std_err      z  p-value   CI_l   CI_r   sig
# feature
# city_people               0.3369    0.071  4.745    0.000  0.198  0.476  ****
# sum_change                   NaN      NaN    NaN      NaN    NaN    NaN   NaN
# mean_unempl_days_alltime     NaN      NaN    NaN      NaN    NaN    NaN   NaN
# subsidii                     NaN      NaN    NaN      NaN    NaN    NaN   NaN
# dotation_2022                NaN      NaN    NaN      NaN    NaN    NaN   NaN
# max_drop_manuf               NaN      NaN    NaN      NaN    NaN    NaN   NaN
# vpk                      -0.0009    0.148 -0.006    0.995 -0.292  0.290
# forest                    0.1301    0.139  0.938    0.348 -0.142  0.402
# max_drop                     NaN      NaN    NaN      NaN    NaN    NaN   NaN
# hospital                     NaN      NaN    NaN      NaN    NaN    NaN   NaN
# auto                     -0.1394    0.077 -1.802    0.071 -0.291  0.012     *
# migration                    NaN      NaN    NaN      NaN    NaN    NaN   NaN
# excess_value_after           NaN      NaN    NaN      NaN    NaN    NaN   NaN
# excess_value_before          NaN      NaN    NaN      NaN    NaN    NaN   NaN
# salary                       NaN      NaN    NaN      NaN    NaN    NaN   NaN
# mean_living_subsid           NaN      NaN    NaN      NaN    NaN    NaN   NaN
# zaderzania                   NaN      NaN    NaN      NaN    NaN    NaN   NaN
# poverty_ratio                NaN      NaN    NaN      NaN    NaN    NaN   NaN
# mean_unempl_days             NaN      NaN    NaN      NaN    NaN    NaN   NaN
# sum_drop_manuf           -0.0543    0.068 -0.798    0.425 -0.188  0.079
# sum_drop                     NaN      NaN    NaN      NaN    NaN    NaN   NaN
# sum_change_manuf         -0.1570    0.132 -1.193    0.233 -0.415  0.101
# antiwar_zaderzania           NaN      NaN    NaN      NaN    NaN    NaN   NaN

# %%
#plt.rcParams["figure.figsize"] = (25, 20)
#fig = sm.graphics.plot_partregress_grid(robust)
#fig.tight_layout(pad=1.0)
#plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]

# %%
ren = {'city_people': 'Доля городского\nнаселения',
       'vote_turnout': 'Явка на голосование\n по поправкам',
       'internet': 'Доступ к интернету',
       'poverty_ratio': 'Доля бедного\nнаселения',
       'income': 'Располагаемые ресурсы\nдомохозяйства',
       'subsidii': 'Социальные выплаты\n населению',
       'excessive_voices': 'Избыточные голоса\nна выборах за ЕР',
       'zaderzania': 'Задержания\nна протестных акциях',
       'gossluz': 'Доля госслужащих',
       'cv': 'Регистрируемая безработица',
       'economic_growth': 'Экономический рост (ВРП)',
       'migration': 'Миграция',
       'subsidii_flat': 'Размер жилищной субсидии',
       'subsidised_families_flat': 'Доля семей, получивших\nжилищную субсидию',
       }
r = results.copy().sort_values(by=['sig']).reset_index()
r['feature'] = r['feature'].apply(lambda x: ren[x] if x in ren else x)
#'Безработица по данным резюме портала "Работа в России" (OLS)'
#tree_graph(r, robust=False, title='Безработица по данным резюме портала "Работа в России" (OLS)')
tree_graph(r, robust=False, title='Влияние факторов на мобилизацию')
tree_graph(r, robust=True, title='Влияние факторов на мобилизацию (robust OLS)')

# %%
ren = {'city_people': 'Доля городского\nнаселения',
       'vote_turnout': 'Явка на голосование\n по поправкам',
       'internet': 'Доступ к интернету',
       'poverty_ratio': 'Доля бедного\nнаселения',
       'income': 'Располагаемые ресурсы\nдомохозяйства',
       'subsidii': 'Социальные выплаты\n населению',
       'excessive_voices': 'Избыточные голоса\nна выборах за ЕР',
       'zaderzania': 'Задержания\nна протестных акциях',
       'gossluz': 'Доля госслужащих',
       'cv': 'Регистрируемая безработица',
       'economic_growth': 'Экономический рост (ВРП)',
       'migration': 'Миграция',
       'subsidii_flat': 'Размер жилищной субсидии',
       'subsidised_families_flat': 'Доля семей, получивших\nжилищную субсидию',
       }
r = results.copy().sort_values(by=['sig']).reset_index()
r['feature'] = r['feature'].apply(lambda x: ren[x] if x in ren else x)
#'Безработица по данным резюме портала "Работа в России" (OLS)'
#tree_graph(r, robust=False, title='Безработица по данным резюме портала "Работа в России" (OLS)')
tree_graph(r, robust=False, title='Влияние факторов на мобилизацию')
tree_graph(r, robust=True, title='Влияние факторов на мобилизацию (robust OLS)')

# %% [markdown]
# ## Мобилизация на данных избыточных свадеб + эксцесс

# %%
cols = ['economic_growth',
 'gossluz',
 'income',
 'vote_turnout',
 #'rate_yes',
 'internet',
 'city_people',
 'salary',
 'migration',
 #'hospital',
 'subsidii',
 #'cv',
 #'indebted',
 'poverty_ratio',
 'zaderzania',
 'antiwar_zaderzania',
 'subsidii_flat',
 'subsidised_families_flat',
 'excess_value_before', 'excess_value_after']
tmp = main_df_norm_scaled.dropna(subset=cols + ['weddings'])
X = tmp[cols]
y = tmp['weddings']

# %%
main_df_norm_scaled.dropna(subset=cols + ['weddings'])[['subsidii_flat', 'indebted', 'income']].corr()
# Out:
#                subsidii_flat  indebted    income
# subsidii_flat       1.000000  0.199599  0.313958
# indebted            0.199599  1.000000  0.740418
# income              0.313958  0.740418  1.000000

# %%
selected_features = []
r_squared = []
p_value = []

while len(selected_features) != X.shape[1]:
  next_feat = next_possible_feature(X_npf=X, y_npf=y, current_features=selected_features)
  selected_features.append(next_feat[0])
  r_squared.append(next_feat[1])
  p_value.append(next_feat[2])

feats = pd.DataFrame({
    'feature': selected_features,
    'r_sq': r_squared,
    'p-value': np.round(p_value, 5),
    'sig': [get_stars(i) for i in p_value]
})

feats[['feature', 'r_sq']].plot()
# Out:
# <AxesSubplot:>

# %%
feats
# Out:
#                      feature      r_sq  p-value sig
# 0            economic_growth  0.215983  0.10669
# 1                    gossluz  0.298648  0.02499  **
# 2                     income  0.334276  0.16065
# 3                   internet  0.373596  0.22700
# 4                  migration  0.406046  0.08112   *
# 5              subsidii_flat  0.429986  0.24290
# 6   subsidised_families_flat  0.447473  0.59209
# 7                     salary  0.469062  0.49264
# 8                   subsidii  0.484055  0.69170
# 9              poverty_ratio  0.492087  0.45806
# 10              vote_turnout  0.494926  0.60452
# 11        excess_value_after  0.496851  0.81203
# 12       excess_value_before  0.505362  0.52672
# 13               city_people  0.505659  0.93908
# 14                zaderzania  0.505750  0.94828
# 15        antiwar_zaderzania  0.505750  0.94828

# %%
best_feats = feats.head(10).feature
f = 'weddings ~ 1 + ' + ' + '.join(best_feats)
print(f)
ols = smf.ols(f, main_df_norm_scaled).fit(cov_type='HC1')
print(ols.summary())

robust = smf.rlm(f, main_df_norm_scaled, M=sm.robust.norms.HuberT()).fit() #TrimmedMean(0.5)
print(robust.summary())
# Out:
# weddings ~ 1 + economic_growth + gossluz + income + internet + migration + subsidii_flat + subsidised_families_flat + salary + subsidii + poverty_ratio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               weddings   R-squared:                       0.482
# Model:                            OLS   Adj. R-squared:                  0.382
# Method:                 Least Squares   F-statistic:                     6.203
# Date:                Sun, 26 Feb 2023   Prob (F-statistic):           3.71e-06
# Time:                        19:46:12   Log-Likelihood:                -68.675
# No. Observations:                  63   AIC:                             159.3
# Df Residuals:                      52   BIC:                             182.9
# Df Model:                          10
# Covariance Type:                  HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.0064      0.114      0.056      0.955      -0.218       0.230
# economic_growth             -0.4211      0.183     -2.305      0.021      -0.779      -0.063
# gossluz                      0.4556      0.140      3.247      0.001       0.181       0.731
# income                      -0.0471      0.094     -0.503      0.615      -0.230       0.136
# internet                     0.0688      0.156      0.441      0.660      -0.237       0.375
# migration                   -0.1695      0.102     -1.662      0.097      -0.369       0.030
# subsidii_flat               -1.2729      0.850     -1.498      0.134      -2.938       0.392
# subsidised_families_flat     0.8530      0.787      1.084      0.278      -0.690       2.396
# salary                       0.0631      0.096      0.656      0.512      -0.125       0.252
# subsidii                     0.4403      0.335      1.313      0.189      -0.217       1.098
# poverty_ratio               -0.1621      0.133     -1.216      0.224      -0.423       0.099
# ==============================================================================
# Omnibus:                       12.695   Durbin-Watson:                   1.768
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               14.964
# Skew:                           0.855   Prob(JB):                     0.000563
# Kurtosis:                       4.667   Cond. No.                         13.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:               weddings   No. Observations:                   63
# Model:                            RLM   Df Residuals:                       52
# Method:                          IRLS   Df Model:                           10
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Sun, 26 Feb 2023
# Time:                        19:46:12
# No. Iterations:                    28
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.0933      0.093     -0.998      0.318      -0.277       0.090
# economic_growth             -0.2992      0.083     -3.596      0.000      -0.462      -0.136
# gossluz                      0.4711      0.137      3.427      0.001       0.202       0.741
# income                      -0.0179      0.110     -0.162      0.871      -0.234       0.198
# internet                    -0.0072      0.102     -0.071      0.944      -0.207       0.192
# migration                   -0.1122      0.124     -0.902      0.367      -0.356       0.132
# subsidii_flat               -0.4677      0.500     -0.935      0.350      -1.448       0.512
# subsidised_families_flat     0.0834      0.476      0.175      0.861      -0.849       1.016
# salary                      -0.0335      0.085     -0.396      0.692      -0.199       0.132
# subsidii                     0.3095      0.277      1.119      0.263      -0.233       0.852
# poverty_ratio               -0.1183      0.121     -0.976      0.329      -0.356       0.119
# ============================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .

# %%
base_ols = pd.read_html(ols.summary().tables[1].as_html(), header=0, index_col=0)[0].rename(columns={'P>|z|' : 'p-value',
                                                                            'std err' : 'std_err',
                                                                            '[0.025' : 'CI_l',
                                                                            '0.975]' : 'CI_r'})
base_ols['sig'] = [get_stars(i) for i in base_ols['p-value']]

robust_ols = pd.read_html(robust.summary().tables[1].as_html(), header=0, index_col=0)[0].rename(columns={'P>|z|' : 'p-value',
                                                                            'std err' : 'std_err',
                                                                            '[0.025' : 'CI_l',
                                                                            '0.975]' : 'CI_r'})
robust_ols['sig'] = [get_stars(i) for i in robust_ols['p-value']]
robust_ols = feats.drop(['p-value', 'sig'], axis=1).set_index('feature').join(robust_ols, how='left')
robust_ols.columns = [i+'_robust' for i in robust_ols.columns]

results = robust_ols.join(base_ols, how='left')
results
# Out:
#                           r_sq_robust  coef_robust  std_err_robust  z_robust  \
# feature
# economic_growth              0.215983      -0.2992           0.083    -3.596
# gossluz                      0.298648       0.4711           0.137     3.427
# income                       0.334276      -0.0179           0.110    -0.162
# internet                     0.373596      -0.0072           0.102    -0.071
# migration                    0.406046      -0.1122           0.124    -0.902
# subsidii_flat                0.429986      -0.4677           0.500    -0.935
# subsidised_families_flat     0.447473       0.0834           0.476     0.175
# salary                       0.469062      -0.0335           0.085    -0.396
# subsidii                     0.484055       0.3095           0.277     1.119
# poverty_ratio                0.492087      -0.1183           0.121    -0.976
# vote_turnout                 0.494926          NaN             NaN       NaN
# excess_value_after           0.496851          NaN             NaN       NaN
# excess_value_before          0.505362          NaN             NaN       NaN
# city_people                  0.505659          NaN             NaN       NaN
# zaderzania                   0.505750          NaN             NaN       NaN
# antiwar_zaderzania           0.505750          NaN             NaN       NaN
#
#                           p-value_robust  CI_l_robust  CI_r_robust sig_robust  \
# feature
# economic_growth                    0.000       -0.462       -0.136       ****
# gossluz                            0.001        0.202        0.741        ***
# income                             0.871       -0.234        0.198
# internet                           0.944       -0.207        0.192
# migration                          0.367       -0.356        0.132
# subsidii_flat                      0.350       -1.448        0.512
# subsidised_families_flat           0.861       -0.849        1.016
# salary                             0.692       -0.199        0.132
# subsidii                           0.263       -0.233        0.852
# poverty_ratio                      0.329       -0.356        0.119
# vote_turnout                         NaN          NaN          NaN        NaN
# excess_value_after                   NaN          NaN          NaN        NaN
# excess_value_before                  NaN          NaN          NaN        NaN
# city_people                          NaN          NaN          NaN        NaN
# zaderzania                           NaN          NaN          NaN        NaN
# antiwar_zaderzania                   NaN          NaN          NaN        NaN
#
#                             coef  std_err      z  p-value   CI_l   CI_r  sig
# feature
# economic_growth          -0.4211    0.183 -2.305    0.021 -0.779 -0.063   **
# gossluz                   0.4556    0.140  3.247    0.001  0.181  0.731  ***
# income                   -0.0471    0.094 -0.503    0.615 -0.230  0.136
# internet                  0.0688    0.156  0.441    0.660 -0.237  0.375
# migration                -0.1695    0.102 -1.662    0.097 -0.369  0.030    *
# subsidii_flat            -1.2729    0.850 -1.498    0.134 -2.938  0.392
# subsidised_families_flat  0.8530    0.787  1.084    0.278 -0.690  2.396
# salary                    0.0631    0.096  0.656    0.512 -0.125  0.252
# subsidii                  0.4403    0.335  1.313    0.189 -0.217  1.098
# poverty_ratio            -0.1621    0.133 -1.216    0.224 -0.423  0.099
# vote_turnout                 NaN      NaN    NaN      NaN    NaN    NaN  NaN
# excess_value_after           NaN      NaN    NaN      NaN    NaN    NaN  NaN
# excess_value_before          NaN      NaN    NaN      NaN    NaN    NaN  NaN
# city_people                  NaN      NaN    NaN      NaN    NaN    NaN  NaN
# zaderzania                   NaN      NaN    NaN      NaN    NaN    NaN  NaN
# antiwar_zaderzania           NaN      NaN    NaN      NaN    NaN    NaN  NaN

# %%
plt.rcParams["figure.figsize"] = (25, 20)
fig = sm.graphics.plot_partregress_grid(robust)
fig.tight_layout(pad=1.0)
plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]

# %%
ren = {'city_people': 'Доля городского\nнаселения',
       'vote_turnout': 'Явка на голосование\n по поправкам',
       'internet': 'Доступ к интернету',
       'poverty_ratio': 'Доля бедного\nнаселения',
       'income': 'Располагаемые ресурсы\nдомохозяйства',
       'subsidii': 'Социальные выплаты\n населению',
       'excessive_voices': 'Избыточные голоса\nна выборах за ЕР',
       'zaderzania': 'Задержания\nна протестных акциях',
       'gossluz': 'Доля госслужащих',
       'cv': 'Регистрируемая безработица',
       'economic_growth': 'Экономический рост (ВРП)',
       'migration': 'Миграция',
       'subsidii_flat': 'Размер жилищной субсидии',
       'subsidised_families_flat': 'Доля семей, получивших\nжилищную субсидию',
       }
r = results.copy().sort_values(by=['sig']).reset_index()
r['feature'] = r['feature'].apply(lambda x: ren[x] if x in ren else x)
#'Безработица по данным резюме портала "Работа в России" (OLS)'
#tree_graph(r, robust=False, title='Безработица по данным резюме портала "Работа в России" (OLS)')
tree_graph(r, robust=False, title='Влияние факторов на мобилизацию')
tree_graph(r, robust=True, title='Влияние факторов на мобилизацию (robust OLS)')

# %%
ren = {'city_people': 'Доля городского\nнаселения',
       'vote_turnout': 'Явка на голосование\n по поправкам',
       'internet': 'Доступ к интернету',
       'poverty_ratio': 'Доля бедного\nнаселения',
       'income': 'Располагаемые ресурсы\nдомохозяйства',
       'subsidii': 'Социальные выплаты\n населению',
       'excessive_voices': 'Избыточные голоса\nна выборах за ЕР',
       'zaderzania': 'Задержания\nна протестных акциях',
       'gossluz': 'Доля госслужащих',
       'cv': 'Регистрируемая безработица',
       'economic_growth': 'Экономический рост (ВРП)',
       'migration': 'Миграция',
       'subsidii_flat': 'Размер жилищной субсидии',
       'subsidised_families_flat': 'Доля семей, получивших\nжилищную субсидию',
       }
r = results.copy().sort_values(by=['sig']).reset_index()
r['feature'] = r['feature'].apply(lambda x: ren[x] if x in ren else x)
#'Безработица по данным резюме портала "Работа в России" (OLS)'
#tree_graph(r, robust=False, title='Безработица по данным резюме портала "Работа в России" (OLS)')
tree_graph(r, robust=False, title='Влияние факторов на мобилизацию')
tree_graph(r, robust=True, title='Влияние факторов на мобилизацию (robust OLS)')

# %% [markdown]
# ## Разное

# %%
main_df_norm.sort_values('vote_turnout', ascending=True)[['region_code', 'vote_turnout']]
# Out:
#       region_code  vote_turnout
# 19  4100000000000         44.08
# 15  3800000000000         44.18
# 76  2700000000000         44.24
# 71  7000000000000         44.57
# 32  5100000000000         45.15
# ..            ...           ...
# 5   3200000000000         89.36
# 48   500000000000         89.99
# 46   200000000000         90.83
# 59  1700000000000         92.80
# 79  2000000000000         95.14
#
# [84 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
fig = plt.scatter(main_df_norm_scaled['cv'], main_df_norm_scaled['gossluz'])
#for i, t in enumerate(txt):
#    ax.annotate(t, (main_df_norm_scaled['weddings'][i], main_df_norm_scaled['vote_turnout'][i]))
ax.set_ylabel("weddings")
# Out:
# Text(0, 0.5, 'weddings')

# %%
main_df_norm_scaled.corr()
# Out:
#                                                     economic_growth  \
# economic_growth                                            1.000000
# population                                                -0.002295
# excessive_voices                                           0.200503
# gossluz                                                   -0.188306
# income                                                    -0.104478
# vote_turnout                                               0.055196
# rate_yes                                                   0.150609
# internet                                                  -0.091768
# _8014006                                                  -0.157727
# city_people                                               -0.021522
# mans_only                                                 -0.040354
# salary                                                     0.064319
# subsidii_flat                                             -0.274792
# subsidised_families_flat                                  -0.198540
# migration                                                  0.119373
# hospital                                                   0.081038
# subsidii                                                  -0.133825
# weddings                                                  -0.446259
# region_code                                               -0.093903
# cv                                                        -0.130075
# poteri                                                    -0.096401
# mobiliz                                                    0.007713
# dobrovol                                                  -0.090125
# Место                                                      0.147863
# Соотношение среднедушевого долга по кредитам и ...         0.084745
# indebted                                                  -0.144164
# Изменение задолженности на одного человека за г...        -0.137827
# zaderzania                                                 0.064717
# antiwar_zaderzania                                         0.064717
#
#                                                     population  \
# economic_growth                                      -0.002295
# population                                            1.000000
# excessive_voices                                      0.105517
# gossluz                                              -0.495609
# income                                                0.402793
# vote_turnout                                          0.154201
# rate_yes                                              0.085919
# internet                                              0.321491
# _8014006                                              0.050385
# city_people                                          -0.240172
# mans_only                                            -0.237390
# salary                                               -0.126036
# subsidii_flat                                        -0.247867
# subsidised_families_flat                             -0.229226
# migration                                             0.242265
# hospital                                              0.608212
# subsidii                                             -0.238199
# weddings                                             -0.284422
# region_code                                           0.148993
# cv                                                   -0.413131
# poteri                                               -0.402963
# mobiliz                                              -0.114058
# dobrovol                                             -0.202744
# Место                                                 0.006746
# Соотношение среднедушевого долга по кредитам и ...   -0.048905
# indebted                                              0.104407
# Изменение задолженности на одного человека за г...    0.218261
# zaderzania                                            0.582568
# antiwar_zaderzania                                    0.582568
#
#                                                     excessive_voices  \
# economic_growth                                             0.200503
# population                                                  0.105517
# excessive_voices                                            1.000000
# gossluz                                                    -0.032660
# income                                                     -0.084845
# vote_turnout                                                0.749090
# rate_yes                                                    0.710749
# internet                                                    0.170371
# _8014006                                                    0.192104
# city_people                                                -0.001265
# mans_only                                                  -0.073719
# salary                                                      0.040034
# subsidii_flat                                              -0.080408
# subsidised_families_flat                                   -0.119850
# migration                                                  -0.040485
# hospital                                                    0.088186
# subsidii                                                   -0.081519
# weddings                                                   -0.150776
# region_code                                                -0.052446
# cv                                                         -0.153111
# poteri                                                     -0.007647
# mobiliz                                                     0.063514
# dobrovol                                                   -0.174368
# Место                                                      -0.149041
# Соотношение среднедушевого долга по кредитам и ...         -0.240861
# indebted                                                   -0.224496
# Изменение задолженности на одного человека за г...         -0.196563
# zaderzania                                                 -0.038184
# antiwar_zaderzania                                         -0.038184
#
#                                                      gossluz    income  \
# economic_growth                                    -0.188306 -0.104478
# population                                         -0.495609  0.402793
# excessive_voices                                   -0.032660 -0.084845
# gossluz                                             1.000000  0.212240
# income                                              0.212240  1.000000
# vote_turnout                                       -0.167611 -0.207377
# rate_yes                                           -0.268161 -0.304513
# internet                                            0.100482  0.425696
# _8014006                                           -0.055512 -0.055137
# city_people                                         0.747572  0.248312
# mans_only                                           0.567102  0.184753
# salary                                              0.227117  0.072920
# subsidii_flat                                       0.341544  0.036851
# subsidised_families_flat                            0.259294  0.026048
# migration                                          -0.701322 -0.222604
# hospital                                           -0.501091  0.055751
# subsidii                                            0.714021  0.249382
# weddings                                            0.527879 -0.006387
# region_code                                         0.140292  0.336937
# cv                                                  0.510697  0.042909
# poteri                                              0.472063 -0.204061
# mobiliz                                             0.608821  0.180342
# dobrovol                                            0.261976 -0.046133
# Место                                              -0.246236 -0.320011
# Соотношение среднедушевого долга по кредитам и ... -0.199482 -0.240881
# indebted                                            0.331456  0.654521
# Изменение задолженности на одного человека за г...  0.311196  0.592978
# zaderzania                                         -0.356746 -0.051405
# antiwar_zaderzania                                 -0.356746 -0.051405
#
#                                                     vote_turnout  rate_yes  \
# economic_growth                                         0.055196  0.150609
# population                                              0.154201  0.085919
# excessive_voices                                        0.749090  0.710749
# gossluz                                                -0.167611 -0.268161
# income                                                 -0.207377 -0.304513
# vote_turnout                                            1.000000  0.863882
# rate_yes                                                0.863882  1.000000
# internet                                                0.276876  0.177006
# _8014006                                                0.173286  0.127630
# city_people                                            -0.081531 -0.320261
# mans_only                                              -0.101083 -0.390244
# salary                                                  0.031621  0.026379
# subsidii_flat                                          -0.070008 -0.154769
# subsidised_families_flat                               -0.107483 -0.182802
# migration                                               0.070292  0.200232
# hospital                                                0.229655  0.147671
# subsidii                                               -0.063880 -0.345433
# weddings                                               -0.259541 -0.295334
# region_code                                            -0.110600 -0.146861
# cv                                                     -0.203029 -0.355613
# poteri                                                  0.007936 -0.041816
# mobiliz                                                 0.007832 -0.062064
# dobrovol                                               -0.029512 -0.235212
# Место                                                  -0.005582  0.073188
# Соотношение среднедушевого долга по кредитам и ...     -0.082696 -0.025921
# indebted                                               -0.222262 -0.346861
# Изменение задолженности на одного человека за г...     -0.153524 -0.293736
# zaderzania                                             -0.068640 -0.078795
# antiwar_zaderzania                                     -0.068640 -0.078795
#
#                                                     internet  _8014006  \
# economic_growth                                    -0.091768 -0.157727
# population                                          0.321491  0.050385
# excessive_voices                                    0.170371  0.192104
# gossluz                                             0.100482 -0.055512
# income                                              0.425696 -0.055137
# vote_turnout                                        0.276876  0.173286
# rate_yes                                            0.177006  0.127630
# internet                                            1.000000 -0.030816
# _8014006                                           -0.030816  1.000000
# city_people                                         0.123652  0.027899
# mans_only                                           0.040516  0.006158
# salary                                             -0.082945 -0.021078
# subsidii_flat                                      -0.050535 -0.026227
# subsidised_families_flat                           -0.045993 -0.016567
# migration                                          -0.106027  0.019648
# hospital                                            0.109882  0.019964
# subsidii                                            0.038085  0.006364
# weddings                                            0.054128  0.029310
# region_code                                         0.093490  0.002403
# cv                                                 -0.041669  0.059457
# poteri                                             -0.034896 -0.087228
# mobiliz                                             0.220492 -0.031133
# dobrovol                                           -0.079690 -0.084733
# Место                                              -0.278100 -0.085221
# Соотношение среднедушевого долга по кредитам и ... -0.290816 -0.023129
# indebted                                            0.300003 -0.006200
# Изменение задолженности на одного человека за г...  0.356000 -0.004476
# zaderzania                                          0.052566 -0.066192
# antiwar_zaderzania                                  0.052566 -0.066192
#
#                                                     city_people  ...  \
# economic_growth                                       -0.021522  ...
# population                                            -0.240172  ...
# excessive_voices                                      -0.001265  ...
# gossluz                                                0.747572  ...
# income                                                 0.248312  ...
# vote_turnout                                          -0.081531  ...
# rate_yes                                              -0.320261  ...
# internet                                               0.123652  ...
# _8014006                                               0.027899  ...
# city_people                                            1.000000  ...
# mans_only                                              0.858334  ...
# salary                                                 0.111381  ...
# subsidii_flat                                          0.271140  ...
# subsidised_families_flat                               0.206600  ...
# migration                                             -0.717440  ...
# hospital                                              -0.220885  ...
# subsidii                                               0.869671  ...
# weddings                                               0.352801  ...
# region_code                                            0.264880  ...
# cv                                                     0.443863  ...
# poteri                                                 0.264011  ...
# mobiliz                                                0.611573  ...
# dobrovol                                               0.313078  ...
# Место                                                 -0.283590  ...
# Соотношение среднедушевого долга по кредитам и ...    -0.273717  ...
# indebted                                               0.341875  ...
# Изменение задолженности на одного человека за г...     0.383291  ...
# zaderzania                                             0.073150  ...
# antiwar_zaderzania                                     0.073150  ...
#
#                                                           cv    poteri  \
# economic_growth                                    -0.130075 -0.096401
# population                                         -0.413131 -0.402963
# excessive_voices                                   -0.153111 -0.007647
# gossluz                                             0.510697  0.472063
# income                                              0.042909 -0.204061
# vote_turnout                                       -0.203029  0.007936
# rate_yes                                           -0.355613 -0.041816
# internet                                           -0.041669 -0.034896
# _8014006                                            0.059457 -0.087228
# city_people                                         0.443863  0.264011
# mans_only                                           0.588360  0.264321
# salary                                              0.067560  0.039597
# subsidii_flat                                       0.329347  0.185974
# subsidised_families_flat                            0.319634  0.165867
# migration                                          -0.238980 -0.297519
# hospital                                           -0.257997 -0.333519
# subsidii                                            0.501830  0.272667
# weddings                                            0.435502  0.505694
# region_code                                        -0.031066 -0.188352
# cv                                                  1.000000  0.474446
# poteri                                              0.474446  1.000000
# mobiliz                                            -0.018306  0.287057
# dobrovol                                            0.558219  0.412671
# Место                                              -0.060199  0.096740
# Соотношение среднедушевого долга по кредитам и ...  0.040119  0.066696
# indebted                                            0.347287 -0.004291
# Изменение задолженности на одного человека за г...  0.273598  0.051335
# zaderzania                                         -0.065981 -0.171559
# antiwar_zaderzania                                 -0.065981 -0.171559
#
#                                                      mobiliz  dobrovol  \
# economic_growth                                     0.007713 -0.090125
# population                                         -0.114058 -0.202744
# excessive_voices                                    0.063514 -0.174368
# gossluz                                             0.608821  0.261976
# income                                              0.180342 -0.046133
# vote_turnout                                        0.007832 -0.029512
# rate_yes                                           -0.062064 -0.235212
# internet                                            0.220492 -0.079690
# _8014006                                           -0.031133 -0.084733
# city_people                                         0.611573  0.313078
# mans_only                                           0.175555  0.527535
# salary                                              0.189044 -0.034307
# subsidii_flat                                       0.079713  0.261097
# subsidised_families_flat                            0.040973  0.269847
# migration                                          -0.659328 -0.100875
# hospital                                           -0.124066 -0.129337
# subsidii                                            0.512271  0.517589
# weddings                                            0.412828  0.105814
# region_code                                         0.181321 -0.081078
# cv                                                 -0.018306  0.558219
# poteri                                              0.287057  0.412671
# mobiliz                                             1.000000 -0.083529
# dobrovol                                           -0.083529  1.000000
# Место                                              -0.234762  0.033918
# Соотношение среднедушевого долга по кредитам и ... -0.275930  0.009831
# indebted                                            0.198433  0.059373
# Изменение задолженности на одного человека за г...  0.263525  0.047144
# zaderzania                                          0.247265 -0.042360
# antiwar_zaderzania                                  0.247265 -0.042360
#
#                                                        Место  \
# economic_growth                                     0.147863
# population                                          0.006746
# excessive_voices                                   -0.149041
# gossluz                                            -0.246236
# income                                             -0.320011
# vote_turnout                                       -0.005582
# rate_yes                                            0.073188
# internet                                           -0.278100
# _8014006                                           -0.085221
# city_people                                        -0.283590
# mans_only                                          -0.209170
# salary                                              0.012184
# subsidii_flat                                      -0.062805
# subsidised_families_flat                           -0.035690
# migration                                           0.318213
# hospital                                            0.254134
# subsidii                                           -0.298153
# weddings                                           -0.191497
# region_code                                        -0.245068
# cv                                                 -0.060199
# poteri                                              0.096740
# mobiliz                                            -0.234762
# dobrovol                                            0.033918
# Место                                               1.000000
# Соотношение среднедушевого долга по кредитам и ...  0.905277
# indebted                                            0.127961
# Изменение задолженности на одного человека за г...  0.100421
# zaderzania                                          0.200943
# antiwar_zaderzania                                  0.200943
#
#                                                     Соотношение среднедушевого долга по кредитам и годовой зарплаты в начале 2022 г., %  \
# economic_growth                                                                              0.084745
# population                                                                                  -0.048905
# excessive_voices                                                                            -0.240861
# gossluz                                                                                     -0.199482
# income                                                                                      -0.240881
# vote_turnout                                                                                -0.082696
# rate_yes                                                                                    -0.025921
# internet                                                                                    -0.290816
# _8014006                                                                                    -0.023129
# city_people                                                                                 -0.273717
# mans_only                                                                                   -0.169362
# salary                                                                                      -0.010277
# subsidii_flat                                                                               -0.018183
# subsidised_families_flat                                                                     0.005387
# migration                                                                                    0.275673
# hospital                                                                                     0.224614
# subsidii                                                                                    -0.283576
# weddings                                                                                    -0.108894
# region_code                                                                                 -0.186397
# cv                                                                                           0.040119
# poteri                                                                                       0.066696
# mobiliz                                                                                     -0.275930
# dobrovol                                                                                     0.009831
# Место                                                                                        0.905277
# Соотношение среднедушевого долга по кредитам и ...                                           1.000000
# indebted                                                                                     0.262018
# Изменение задолженности на одного человека за г...                                           0.185730
# zaderzania                                                                                   0.223190
# antiwar_zaderzania                                                                           0.223190
#
#                                                     indebted  \
# economic_growth                                    -0.144164
# population                                          0.104407
# excessive_voices                                   -0.224496
# gossluz                                             0.331456
# income                                              0.654521
# vote_turnout                                       -0.222262
# rate_yes                                           -0.346861
# internet                                            0.300003
# _8014006                                           -0.006200
# city_people                                         0.341875
# mans_only                                           0.290945
# salary                                              0.107727
# subsidii_flat                                       0.123769
# subsidised_families_flat                            0.139794
# migration                                          -0.192660
# hospital                                            0.021554
# subsidii                                            0.306406
# weddings                                            0.249747
# region_code                                         0.266363
# cv                                                  0.347287
# poteri                                             -0.004291
# mobiliz                                             0.198433
# dobrovol                                            0.059373
# Место                                               0.127961
# Соотношение среднедушевого долга по кредитам и ...  0.262018
# indebted                                            1.000000
# Изменение задолженности на одного человека за г...  0.874622
# zaderzania                                          0.018609
# antiwar_zaderzania                                  0.018609
#
#                                                     Изменение задолженности на одного человека за год, тыс. руб.  \
# economic_growth                                                                             -0.137827
# population                                                                                   0.218261
# excessive_voices                                                                            -0.196563
# gossluz                                                                                      0.311196
# income                                                                                       0.592978
# vote_turnout                                                                                -0.153524
# rate_yes                                                                                    -0.293736
# internet                                                                                     0.356000
# _8014006                                                                                    -0.004476
# city_people                                                                                  0.383291
# mans_only                                                                                    0.328651
# salary                                                                                       0.098907
# subsidii_flat                                                                                0.058055
# subsidised_families_flat                                                                     0.071730
# migration                                                                                   -0.194677
# hospital                                                                                     0.055664
# subsidii                                                                                     0.354040
# weddings                                                                                     0.321883
# region_code                                                                                  0.149638
# cv                                                                                           0.273598
# poteri                                                                                       0.051335
# mobiliz                                                                                      0.263525
# dobrovol                                                                                     0.047144
# Место                                                                                        0.100421
# Соотношение среднедушевого долга по кредитам и ...                                           0.185730
# indebted                                                                                     0.874622
# Изменение задолженности на одного человека за г...                                           1.000000
# zaderzania                                                                                   0.104454
# antiwar_zaderzania                                                                           0.104454
#
#                                                     zaderzania  \
# economic_growth                                       0.064717
# population                                            0.582568
# excessive_voices                                     -0.038184
# gossluz                                              -0.356746
# income                                               -0.051405
# vote_turnout                                         -0.068640
# rate_yes                                             -0.078795
# internet                                              0.052566
# _8014006                                             -0.066192
# city_people                                           0.073150
# mans_only                                            -0.015737
# salary                                               -0.123106
# subsidii_flat                                        -0.127947
# subsidised_families_flat                             -0.125225
# migration                                             0.107735
# hospital                                              0.557796
# subsidii                                             -0.144756
# weddings                                             -0.115614
# region_code                                           0.069375
# cv                                                   -0.065981
# poteri                                               -0.171559
# mobiliz                                               0.247265
# dobrovol                                             -0.042360
# Место                                                 0.200943
# Соотношение среднедушевого долга по кредитам и ...    0.223190
# indebted                                              0.018609
# Изменение задолженности на одного человека за г...    0.104454
# zaderzania                                            1.000000
# antiwar_zaderzania                                    1.000000
#
#                                                     antiwar_zaderzania
# economic_growth                                               0.064717
# population                                                    0.582568
# excessive_voices                                             -0.038184
# gossluz                                                      -0.356746
# income                                                       -0.051405
# vote_turnout                                                 -0.068640
# rate_yes                                                     -0.078795
# internet                                                      0.052566
# _8014006                                                     -0.066192
# city_people                                                   0.073150
# mans_only                                                    -0.015737
# salary                                                       -0.123106
# subsidii_flat                                                -0.127947
# subsidised_families_flat                                     -0.125225
# migration                                                     0.107735
# hospital                                                      0.557796
# subsidii                                                     -0.144756
# weddings                                                     -0.115614
# region_code                                                   0.069375
# cv                                                           -0.065981
# poteri                                                       -0.171559
# mobiliz                                                       0.247265
# dobrovol                                                     -0.042360
# Место                                                         0.200943
# Соотношение среднедушевого долга по кредитам и ...            0.223190
# indebted                                                      0.018609
# Изменение задолженности на одного человека за г...            0.104454
# zaderzania                                                    1.000000
# antiwar_zaderzania                                            1.000000
#
# [29 rows x 29 columns]

# %%
import plotly.express as px
fig = px.imshow(main_df_norm_scaled.corr())
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="13680a28-50b5-4950-ab97-35542e4417dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13680a28-50b5-4950-ab97-35542e4417dd")) {                    Plotly.newPlot(                        "13680a28-50b5-4950-ab97-35542e4417dd",                        [{"coloraxis":"coloraxis","name":"0","x":["economic_growth","population","excessive_voices","gossluz","income","vote_turnout","rate_yes","internet","_8014006","city_people","mans_only","salary","subsidii_flat","subsidised_families_flat","migration","hospital","subsidii","weddings","region_code","cv","poteri","mobiliz","dobrovol","\u041c\u0435\u0441\u0442\u043e","\u0421\u043e\u043e\u0442\u043d\u043e\u0448\u0435\u043d\u0438\u0435 \u0441\u0440\u0435\u0434\u043d\u0435\u0434\u0443\u0448\u0435\u0432\u043e\u0433\u043e \u0434\u043e\u043b\u0433\u0430 \u043f\u043e \u043a\u0440\u0435\u0434\u0438\u0442\u0430\u043c \u0438 \u0433\u043e\u0434\u043e\u0432\u043e\u0439 \u0437\u0430\u0440\u043f\u043b\u0430\u0442\u044b \u0432 \u043d\u0430\u0447\u0430\u043b\u0435 2022 \u0433., %","indebted","\u0418\u0437\u043c\u0435\u043d\u0435\u043d\u0438\u0435 \u0437\u0430\u0434\u043e\u043b\u0436\u0435\u043d\u043d\u043e\u0441\u0442\u0438 \u043d\u0430\u00a0\u043e\u0434\u043d\u043e\u0433\u043e \u0447\u0435\u043b\u043e\u0432\u0435\u043a\u0430 \u0437\u0430\u00a0\u0433\u043e\u0434, \u0442\u044b\u0441. \u0440\u0443\u0431.","zaderzania","antiwar_zaderzania"],"y":["economic_growth","population","excessive_voices","gossluz","income","vote_turnout","rate_yes","internet","_8014006","city_people","mans_only","salary","subsidii_flat","subsidised_families_flat","migration","hospital","subsidii","weddings","region_code","cv","poteri","mobiliz","dobrovol","\u041c\u0435\u0441\u0442\u043e","\u0421\u043e\u043e\u0442\u043d\u043e\u0448\u0435\u043d\u0438\u0435 \u0441\u0440\u0435\u0434\u043d\u0435\u0434\u0443\u0448\u0435\u0432\u043e\u0433\u043e \u0434\u043e\u043b\u0433\u0430 \u043f\u043e \u043a\u0440\u0435\u0434\u0438\u0442\u0430\u043c \u0438 \u0433\u043e\u0434\u043e\u0432\u043e\u0439 \u0437\u0430\u0440\u043f\u043b\u0430\u0442\u044b \u0432 \u043d\u0430\u0447\u0430\u043b\u0435 2022 \u0433., %","indebted","\u0418\u0437\u043c\u0435\u043d\u0435\u043d\u0438\u0435 \u0437\u0430\u0434\u043e\u043b\u0436\u0435\u043d\u043d\u043e\u0441\u0442\u0438 \u043d\u0430\u00a0\u043e\u0434\u043d\u043e\u0433\u043e \u0447\u0435\u043b\u043e\u0432\u0435\u043a\u0430 \u0437\u0430\u00a0\u0433\u043e\u0434, \u0442\u044b\u0441. \u0440\u0443\u0431.","zaderzania","antiwar_zaderzania"],"z":[[1.0,-0.0022953394931550936,0.2005027027937351,-0.18830591487117196,-0.10447824336889804,0.05519636289979541,0.1506086866592886,-0.09176812893971653,-0.15772720234961868,-0.02152235258023624,-0.04035387267136964,0.06431902761731227,-0.2747924619286611,-0.19854046236457062,0.11937263891654465,0.08103789433109666,-0.13382485863036897,-0.44625935117677185,-0.09390263171448883,-0.13007470256211218,-0.09640127524610917,0.0077132465824370985,-0.09012475830601543,0.1478631005271494,0.08474504649774783,-0.1441642431961671,-0.1378271118329018,0.06471652160874024,0.06471652160874024],[-0.0022953394931550936,1.0,0.10551734075546153,-0.4956093114198869,0.40279266737840314,0.15420101206818376,0.08591941611392047,0.32149094758027313,0.05038537007850249,-0.240172443060291,-0.2373902096484117,-0.1260363862152224,-0.2478668436035772,-0.22922631033686727,0.24226534705343652,0.6082116868109849,-0.2381991504727303,-0.28442225636584173,0.14899261983542672,-0.41313054004878585,-0.4029632618735982,-0.11405771073386863,-0.202744167988824,0.006746071577347544,-0.04890510009103425,0.10440670432715568,0.21826104860043105,0.5825678302852795,0.5825678302852795],[0.2005027027937351,0.10551734075546153,1.0,-0.032660356402076304,- ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
fig = plt.scatter(main_df_norm_scaled['weddings'], main_df_norm_scaled['vote_turnout'])
#for i, t in enumerate(txt):
#    ax.annotate(t, (main_df_norm_scaled['weddings'][i], main_df_norm_scaled['vote_turnout'][i]))
ax.set_ylabel("weddings")
ax.set_xlabel("vote_turnout")
# Out:
# Text(0.5, 0, 'vote_turnout')

# %%
fig, ax = plt.subplots()
fig = sm.graphics.plot_fit(robust, 4, ax=ax, vlines=False)
ax.set_ylabel("weddings")
#ax.set_xlabel("Poverty Level")
ax.set_title(f)
# Out:
# Text(0.5, 1.0, 'weddings ~ 1 + cv + economic_growth + gossluz + subsidii_flat + subsidised_families_flat + salary + income + subsidii')

# %%
# %%capture
# !pip install semopy
import semopy as sem

# %%
main_df_norm_scaled
# Out:
#     economic_growth  population  excessive_voices   gossluz    income  \
# 0          0.866882    0.304485         -0.744301 -0.197113 -0.608723
# 1         -3.009655   -0.552117         -0.561823  0.327681  0.042430
# 2          0.309471   -0.381257         -1.300807 -0.231579  2.437206
# 3          3.628598   -0.429231          0.299881 -0.232462 -0.124047
# 4          0.233461   -0.132488          0.745406 -0.494205 -0.085236
# ..              ...         ...               ...       ...       ...
# 79        -0.830687   -0.182821          2.047833 -0.384613 -0.949408
# 80        -0.856023   -0.312765         -0.164852 -0.707910 -0.713654
# 81        -0.247939   -0.965798          0.705389  4.877959  1.245019
# 82         0.461493   -0.439158          1.417695  1.190537  3.905613
# 83         0.208124   -0.292615         -1.170618 -0.347795 -0.384825
#
#     vote_turnout  rate_yes  internet  _8014006  city_people  ...  subsidii  \
# 0      -1.260881 -0.438350 -0.990731 -0.121728    -0.336482  ... -0.374578
# 1      -0.544012 -0.597209  0.480139 -0.122400    -0.253071  ... -0.177103
# 2      -1.180159 -1.091913 -0.295049 -0.105498    -0.189465  ... -0.119417
# 3       0.510556  1.141716  0.360879 -0.121531    -0.674605  ... -0.277002
# 4       0.977854  0.611829 -0.950978 -0.110024    -0.256671  ... -0.043851
# ..           ...       ...       ...       ...          ...  ...       ...
# 79      2.119808  2.334761  1.951009 -0.133226    -0.354922  ... -0.268267
# 80     -0.178172 -0.367983 -1.249127 -0.111124     0.014580  ... -0.262446
# 81      0.681627  0.456168  1.414340 -0.092271     4.087242  ...  4.473456
# 82      1.054873  1.400795  2.348541 -0.111333    -0.272832  ... -0.121335
# 83     -0.789880 -0.824304 -0.632952 -0.104854    -0.179122  ... -0.091301
#
#     weddings  region_code        cv    poteri   mobiliz  dobrovol  zaderzania  \
# 0   0.287209    -0.839666 -0.103646 -0.288497 -0.314968 -0.404579   -0.205610
# 1   3.635036    -0.597566  0.048211 -0.232196 -0.142702 -0.772759   -0.214870
# 2  -0.530543    -0.557215  0.537629 -0.346698 -0.275442  0.050833   -0.175302
# 3  -0.496245    -0.516865 -0.113509 -0.189735 -0.269081 -0.290995   -0.208135
# 4  -0.172351    -0.476515  0.565923 -0.068980  0.447667 -0.107891   -0.057439
# ..       ...          ...       ...       ...       ...       ...         ...
# 79       NaN    -0.920366 -0.659756  0.049959 -0.350254  3.456444         NaN
# 80 -0.769397    -0.880016 -0.374144 -0.021541 -0.282970  0.236304   -0.207293
# 81       NaN     1.783089 -0.529765  1.389902  7.937044 -0.880408         NaN
# 82 -0.747912     1.863790 -0.348697 -1.257111 -0.350254 -0.537568   -0.216554
# 83 -0.741540     1.339239 -0.425218 -0.737747 -0.284905  0.000832   -0.166883
#
#     antiwar_zaderzania  mean_living_subsid
# 0            -0.205610           -0.006257
# 1            -0.214870           -0.119320
# 2            -0.175302           -0.423816
# 3            -0.208135           -0.290685
# 4            -0.057439           -0.087317
# ..                 ...                 ...
# 79                 NaN           -0.072078
# 80           -0.207293            0.594711
# 81                 NaN            0.433521
# 82           -0.216554           -0.130199
# 83           -0.166883            0.003843
#
# [84 rows x 26 columns]

# %%
formula = """
weddings ~~ poteri

C =~ cv + economic_growth + income + subsidii + salary + gossluz
weddings ~ C + zaderzania + excessive_voices + internet
poteri ~ C + zaderzania + excessive_voices + internet
"""
model = sem.Model(formula)
model.fit(main_df_norm_scaled, obj="MLW", solver="SLSQP") #MLW ULS GLS FIML DWLS WLS
sem.bias_correction(model, n=100, resample_mean=True)
print(sem.calc_stats(model).T)
sem.semplot(model, "fig19.pdf", plot_covs=True, std_ests=True, show=True)
# Out:
#                       Value
# DoF            4.300000e+01
# DoF Baseline   5.800000e+01
# chi2           1.351751e+02
# chi2 p-value   1.853140e-11
# chi2 Baseline  2.980239e+02
# CFI            6.159755e-01
# GFI            5.464288e-01
# AGFI           3.882063e-01
# NFI            5.464288e-01
# TLI            4.820134e-01
# RMSEA          1.607065e-01
# AIC            4.275600e+01
# BIC            9.866478e+01
# LogLik         1.622001e+00
